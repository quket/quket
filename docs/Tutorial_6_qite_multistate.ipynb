# %% [markdown]
# # Tutorial (6): QITE and Multistate calculation
#
# Here we show how to run QITE especially with a model space

# %% [markdown]
# [(1) Classical imaginary-time-evolution](#(1)-Classical-imaginary-time-evolution)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Initializing CITE](#Initializing-CITE)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Running CITE](#Running-CITE)
#
# [(2) UCCGSD-based QITE](#(2)-UCCGSD-based-QITE)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Initializing QITE](#Initializing-QITE)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Running QITE](#Running-QITE)
#
# [(3) Model-Space QITE](#(3)-Model-Space-QITE)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Initializing MSQITE](#Initializing-MSQITE)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Example of structure of `multi`](#Example-of-structure-of-multi)
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;[Running MSQITE](#Running-MSQITE)

# %%
# import necessary modules
from quket import *
from quket.utils import *
import quket.config as cf
# Out:
# mpi4py is not imported. no MPI.

# %% [markdown]
# ## (1) Classical imaginary-time-evolution
# Setting `method = qite` updates the state based on imaginary-time-evolution:
# \begin{equation}
# |\Phi^{(k+1)}\rangle = \frac{e^{-\Delta\beta \hat H} |\Phi^{(k)}\rangle}{\langle \Phi^{(k)} | e^{-2\Delta\beta \hat H} |\Phi^{(k)}\rangle}
# \end{equation}
# First, we consider to perform the above non-unitary operation numerically exactly by `ansatz = cite` (classical ITE).
# $\Delta\beta$ is set with `dt`, `db`, or `timestep`.

# %% [markdown]
# ### Initializing CITE

# %%
### Create QuketData for H4 example ###
CITE = create(
    basis        = 'sto-6G',
    multiplicity = 1,
    charge       = 0,
    n_electrons  = 4,
    n_orbitals   = 4,
    geometry     = "H  0  0  0    ;\
                    H  0  0  1.2  ;\
                    H  1  0  0    ;\
                    H  1  0  1.2 ",
    method       = 'qite',
    ansatz       = 'cite',
    dt           = 0.2,
    maxiter      = 1000,
    det          = '00001111',
    taper_off    = True,
    run_qubitfci = True
)
# Out:
# Basis set = sto-6G
#
# *** Geometry ******************************
#   H     0.0000000    0.0000000    0.0000000
#   H     0.0000000    0.0000000    1.2000000
#   H     1.0000000    0.0000000    0.0000000
#   H     1.0000000    0.0000000    1.2000000
# *******************************************
#
# Symmetry D2h : D2h(Abelian)
# E[FCI]    = -2.033812422170     (Spin = 1   Ms = 0)
# E[HF]     = -1.939420943306     (Spin = 1   Ms = 0)
# TODO: Pauli_list is not supported for ansatz = cite.
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z6]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5 Z6 Z7]
#
# States     transformed.
# Overwritten attributes  contract_2e  of <class 'pyscf.fci.direct_spin1_symm.FCISolver'>
# Operators  transformed.
# NBasis = 4
# States     backtransformed.
# Operators  backtransformed.
# States     transformed.
# Operators  transformed.
# FCI in Qubits (tapered-off mapping)
# (FCI state : E = -2.0338124221702545)
#   Basis          Coef
# | 0001 > : +0.9391 +0.0000i
# | 0010 > : -0.2519 +0.0000i
# | 0111 > : -0.1083 +0.0000i
# | 1000 > : -0.1083 +0.0000i

# %% [markdown]
# ### Running CITE

# %%
CITE.run()
# Out:
# Enetered QITE driver
# Performing QITE for chemical Hamiltonian
# Ansatz = cite
# Initial configuration: | 00001111 >
# Convergence criteria: ftol = 1E-09
# ITE
# Shift =  -1.9394209433056588
# QLanczos =  False
#   0.00: E = -1.939420943306  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0
<S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  20.40: E = -2.033812357205  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  20.60: E = -2.033812364733  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  20.80: E = -2.033812371389  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  21.00: E = -2.033812377273  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  21.20: E = -2.033812382475  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  21.40: E = -2.033812387075  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  21.60: E = -2.033812391142  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  21.80: E = -2.033812394737  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  22.00: E = -2.033812397916  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  22.20: E = -2.033812400726  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  22.40: E = -2.033812403211  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.04
#  22.60: E = -2.033812405408  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  22.80: E = -2.033812407350  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  23.00: E = -2.033812409068  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.06
#  23.20: E = -2.033812410586  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.09
#  23.40: E = -2.033812411928  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.06
#  23.60: E = -2.033812413115  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  23.80: E = -2.033812414164  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
#  24.00: E = -2.033812415092  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 1.000000  CPU Time =  0.05
# CONVERGED at beta=24.00.
#  Final: E[cite] = -2.033812415092  <S**2> = -0.000000000000000
# (QITE state)
#   Basis          Coef
# | 0001 > : +0.9392 +0.0000i
# | 0010 > : -0.2518 +0.0000i
# | 0111 > : -0.1083 +0.0000i
# | 1000 > : -0.1083 +0.0000i

# %% [markdown]
# ## (2) UCCGSD-based QITE
# Setting `ansatz` to a pre-defined ansatz in `qite_ansatz_list`, `config.py`, prepares an operator pool.
# Here, we set `ansatz = uccgsd`.
#
# Also, change the initial state to `0.9391 * |00001111> - 0.2518 * |00110011>` to accelerate the convergence.

# %% [markdown]
# #### Initializing QITE

# %%
QITE = CITE.copy()
QITE.set(ansatz = 'uccgsd', det="0.9391 * |00001111> - 0.2518 * |00110011>")
QITE.initialize()
# Out:
# Basis set = sto-6G
#
# *** Geometry ******************************
#   H     0.0000000    0.0000000    0.0000000
#   H     0.0000000    0.0000000    1.2000000
#   H     1.0000000    0.0000000    0.0000000
#   H     1.0000000    0.0000000    1.2000000
# *******************************************
#
# Symmetry D2h : D2h(Abelian)
# E[FCI]    = -2.033812422170     (Spin = 1   Ms = 0)
# E[HF]     = -1.939420943306     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z6]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5 Z6 Z7]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.

# %% [markdown]
# #### Running UCCGSD-based QITE

# %%
QITE.run()
# Out:
# Enetered QITE driver
# Performing QITE for chemical Hamiltonian
# Ansatz = uccgsd
# Initial configuration:  +0.9391+0.0000j * | 00001111 > -0.2518+0.0000j * | 00110011 >
# Convergence criteria: ftol = 1E-09
# QITE: Pauli operator group size = 30
# Timing for preparing nonredundant sigma list: 0.0 sec
#     Unique sigma list = 71
# Shift =  -1.9596549885611783
# QLanczos =  False
#   0.00: E = -1.959654988561  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.00
#   0.20: E = -1.994102853769  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   0.40: E = -2.012484390895  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   0.60: E = -2.022225735883  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   0.80: E = -2.027415162393  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   1.00: E = -2.030212805871  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   1.20: E = -2.031745220195  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   1.40: E = -2.032600151238  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   1.60: E = -2.033086621297  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   1.80: E = -2.033369094042  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   2.00: E = -2.033536431782  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   2.20: E = -2.033637484000  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   2.40: E = -2.033699612307  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   2.60: E = -2.033738445276  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   2.80: E = -2.033763087111  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   3.00: E = -2.033778943548  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   3.20: E = -2.033789282284  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   3.40: E = -2.033796111024  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   3.60: E = -2.033800681272  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   3.80: E = -2.033803783035  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   4.00: E = -2.033805920461  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   4.20: E = -2.033807418331  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   4.40: E = -2.033808487633  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   4.60: E = -2.033809266488  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   4.80: E = -2.033809845990  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#   5.00: E = -2.033810286669  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#   5.20: E = -2.033810629082  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   5.40: E = -2.033810900650  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   5.60: E = -2.033811120111  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.04
#   5.80: E = -2.033811300434  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   6.00: E = -2.033811450719  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   6.20: E = -2.033811577465  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   6.40: E = -2.033811685396  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   6.60: E = -2.033811778018  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   6.80: E = -2.033811857987  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   7.00: E = -2.033811927359  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   7.20: E = -2.033811987758  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   7.40: E = -2.033812040491  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   7.60: E = -2.033812086629  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   7.80: E = -2.033812127062  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#   8.00: E = -2.033812162539  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   8.20: E = -2.033812193695  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   8.40: E = -2.033812221076  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   8.60: E = -2.033812245151  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   8.80: E = -2.033812266328  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   9.00: E = -2.033812284962  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   9.20: E = -2.033812301360  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   9.40: E = -2.033812315794  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   9.60: E = -2.033812328500  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#   9.80: E = -2.033812339687  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#  10.00: E = -2.033812349537  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  10.20: E = -2.033812358209  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  10.40: E = -2.033812365845  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.03
#  10.60: E = -2.033812372570  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  10.80: E = -2.033812378491  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  11.00: E = -2.033812383705  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  11.20: E = -2.033812388297  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  11.40: E = -2.033812392340  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  11.60: E = -2.033812395901  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  11.80: E = -2.033812399037  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  12.00: E = -2.033812401798  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  12.20: E = -2.033812404230  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  12.40: E = -2.033812406371  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  12.60: E = -2.033812408257  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  12.80: E = -2.033812409918  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  13.00: E = -2.033812411381  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  13.20: E = -2.033812412668  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  13.40: E = -2.033812413803  <S**2> = -0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
#  13.60: E = -2.033812414801  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.02
# CONVERGED at beta=13.60.
#  Final: E[uccgsd] = -2.033812414801  <S**2> = +0.000000000000001
# (QITE state)
#   Basis          Coef
# | 0001 > : +0.9391 +0.0000i
# | 0010 > : -0.2521 +0.0000i
# | 0111 > : -0.1083 +0.0000i
# | 1000 > : -0.1083 +0.0000i

# %% [markdown]
# ## (3) Model-Space QITE
# MSQITE is invoked by `msqite = True` with `method = qite`.
#
# Some algorithms including MSQITE need multiple `state`s and `init_state`s.
# These states are defined by `multi` option and handled by the `multi` subclass.
#
# `multi` option requires a list of state descriptions.
# Each state description is given by a tuple (or list) of initial state (single determinant or multi determinants) and weight
# ```python
#    multi = [(det1, weight1), (det2, weight2)]
# ```
# Here, weight1, weight2, ... are a positive number for state-averaging (thus will be normalized),
# and det1, det2, ... are specified in the same way as `det`.
#
# For MSQITE, weights play no role.

# %% [markdown]
# #### Initializing MSQITE

# %%
MSQITE = QITE.copy()
MSQITE.set(multi=[("|00001111>", 1), ("0.6 *|00110011> - 0.3 *|11000011>", 1)], msqite=True)
MSQITE.initialize()
# Out:
# Basis set = sto-6G
#
# *** Geometry ******************************
#   H     0.0000000    0.0000000    0.0000000
#   H     0.0000000    0.0000000    1.2000000
#   H     1.0000000    0.0000000    0.0000000
#   H     1.0000000    0.0000000    1.2000000
# *******************************************
#
# Symmetry D2h : D2h(Abelian)
# E[FCI]    = -2.033812422170     (Spin = 1   Ms = 0)
# E[HF]     = -1.939420943306     (Spin = 1   Ms = 0)
# Existing theta_list is inconsistent :
#    size of pauli_list 162 != size of theta_list 30.
# Ovewrite theta_list by zero.
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z6]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5 Z6 Z7]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.

# %% [markdown]
# #### Example of structure of `multi`
# `init_state_info` contains initial configurations: single-determinants/multi-determinants

# %%
print(MSQITE.multi.init_states_info)
# Base-10 integer = Determinant"
# Out:
# [15, [[(0.6+0j), 51], [(-0.3+0j), 195]]]

# %% [markdown]
# This result means we have two configurations,
# ```python
# 15
# ```
# and
# ```python
# [[(0.6+0j), 15], [(-0.3+0j), 195]]
# ```
# Single determinants are represented by a base-10 integer.
# A multi determinant description is given by a list of tuples of (`coefficient`, `determinant` (base-10))

# %%
for k, (state, weight) in enumerate(zip(MSQITE.multi.states, MSQITE.multi.weights)):
    print_state(state, f"{k}-th state in multi. Weight = {weight}")
# Out:
# 0-th state in multi. Weight = 1.0
#   Basis          Coef
# | 0001 > : +1.0000 +0.0000i
#
# 1-th state in multi. Weight = 1.0
#   Basis          Coef
# | 0010 > : +0.8944 +0.0000i
# | 1100 > : -0.4472 +0.0000i

# %% [markdown]
# #### Running MSQITE

# %%
MSQITE.run()
# Out:
# Enetered QITE driver
# Performing QITE for chemical Hamiltonian
# Ansatz = uccgsd
# Initial configuration:  +0.9391+0.0000j * | 00001111 > -0.2518+0.0000j * | 00110011 >
# Convergence criteria: ftol = 1E-09
# MSQITE (State-Specific): Pauli operator group size = 30
# Timing for preparing nonredundant sigma list: 0.0 sec
#     Unique sigma list = 71
# Initial state 0
#   Basis          Coef
# | 0001 > : +1.0000 +0.0000i
#
# Initial state 1
#   Basis          Coef
# | 0010 > : +0.8944 +0.0000i
# | 1100 > : -0.4472 +0.0000i
#
# Shift =  [(-1.9394209433056593+0j), (-1.5655253081245326+0j)]
# QLanczos =  False
#   0.00
#       state0: E = -1.939787627916  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.01
#       state1: E = -1.565158623514  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.01
#
#   0.20
#       state0: E = -1.977488376452  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.07
#       state1: E = -1.621671913419  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.07
#
#   0.40
#       state0: E = -2.002485375522  <S**2> = +0.00000564  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.658278649798  <S**2> = +0.00000004  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   0.60
#       state0: E = -2.016233868116  <S**2> = +0.00000805  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.682081993116  <S**2> = +0.00000008  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   0.80
#       state0: E = -2.023886018904  <S**2> = +0.00001032  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.697488232901  <S**2> = +0.00000013  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   1.00
#       state0: E = -2.028124127191  <S**2> = +0.00001160  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.707440887869  <S**2> = +0.00000019  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   1.20
#       state0: E = -2.030491155446  <S**2> = +0.00001184  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.713866219171  <S**2> = +0.00000024  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   1.40
#       state0: E = -2.031833929579  <S**2> = +0.00001127  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.718018160531  <S**2> = +0.00000027  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   1.60
#       state0: E = -2.032610427828  <S**2> = +0.00001014  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.720707923048  <S**2> = +0.00000028  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   1.80
#       state0: E = -2.033068554264  <S**2> = +0.00000867  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.722457572863  <S**2> = +0.00000028  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   2.00
#       state0: E = -2.033344071449  <S**2> = +0.00000693  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.09
#       state1: E = -1.723601923690  <S**2> = +0.00000025  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.09
#
#   2.20
#       state0: E = -2.033512885343  <S**2> = +0.00000512  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.724355302488  <S**2> = +0.00000021  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   2.40
#       state0: E = -2.033615647679  <S**2> = +0.00000596  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.724854183035  <S**2> = +0.00000028  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   2.60
#       state0: E = -2.033675083016  <S**2> = +0.00000514  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725187484262  <S**2> = +0.00000027  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   2.80
#       state0: E = -2.033724759339  <S**2> = +0.00000011  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725414638330  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   3.00
#       state0: E = -2.033760974934  <S**2> = +0.00000311  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725568118869  <S**2> = +0.00000014  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   3.20
#       state0: E = -2.033780259058  <S**2> = +0.00000280  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725672220567  <S**2> = +0.00000015  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   3.40
#       state0: E = -2.033791862908  <S**2> = +0.00000216  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725744191794  <S**2> = +0.00000013  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   3.60
#       state0: E = -2.033799153556  <S**2> = +0.00000162  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725794430390  <S**2> = +0.00000011  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   3.80
#       state0: E = -2.033803806681  <S**2> = +0.00000121  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725829793905  <S**2> = +0.00000009  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   4.00
#       state0: E = -2.033806803978  <S**2> = +0.00000090  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725854885630  <S**2> = +0.00000008  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   4.20
#       state0: E = -2.033808746847  <S**2> = +0.00000067  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725872824187  <S**2> = +0.00000007  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   4.40
#       state0: E = -2.033810011967  <S**2> = +0.00000049  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725885740259  <S**2> = +0.00000006  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   4.60
#       state0: E = -2.033810838566  <S**2> = +0.00000036  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725895101722  <S**2> = +0.00000005  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   4.80
#       state0: E = -2.033811380055  <S**2> = +0.00000027  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725901928232  <S**2> = +0.00000004  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   5.00
#       state0: E = -2.033811735496  <S**2> = +0.00000020  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725906933884  <S**2> = +0.00000003  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   5.20
#       state0: E = -2.033811969194  <S**2> = +0.00000015  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725910622772  <S**2> = +0.00000003  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   5.40
#       state0: E = -2.033812123054  <S**2> = +0.00000011  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725913353482  <S**2> = +0.00000002  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   5.60
#       state0: E = -2.033812224468  <S**2> = +0.00000008  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725915382957  <S**2> = +0.00000002  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   5.80
#       state0: E = -2.033812291380  <S**2> = +0.00000006  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725916896577  <S**2> = +0.00000002  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   6.00
#       state0: E = -2.033812335568  <S**2> = +0.00000004  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725918028948  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   6.20
#       state0: E = -2.033812364775  <S**2> = +0.00000003  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725918878378  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   6.40
#       state0: E = -2.033812384097  <S**2> = +0.00000002  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725919517057  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   6.60
#       state0: E = -2.033812396889  <S**2> = +0.00000002  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725919998246  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   6.80
#       state0: E = -2.033812405365  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725920361413  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   7.00
#       state0: E = -2.033812410987  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725920635919  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   7.20
#       state0: E = -2.033812414720  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725920843676  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   7.40
#       state0: E = -2.033812417200  <S**2> = +0.00000001  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725921001089  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   7.60
#       state0: E = -2.033812418850  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725921120470  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   7.80
#       state0: E = -2.033812419949  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725921211081  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   8.00
#       state0: E = -2.033812420682  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725921279904  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   8.20
#       state0: E = -2.033812421171  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921332208  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   8.40
#       state0: E = -2.033812421498  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921371978  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   8.60
#       state0: E = -2.033812421717  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#       state1: E = -1.725921402230  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.06
#
#   8.80
#       state0: E = -2.033812421865  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921425252  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   9.00
#       state0: E = -2.033812421963  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921442776  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   9.20
#       state0: E = -2.033812422030  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921456119  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   9.40
#       state0: E = -2.033812422075  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921466281  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   9.60
#       state0: E = -2.033812422105  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921474022  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#   9.80
#       state0: E = -2.033812422126  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921479920  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#  10.00
#       state0: E = -2.033812422140  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921484414  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#  10.20
#       state0: E = -2.033812422149  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921487838  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#  10.40
#       state0: E = -2.033812422156  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921490449  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
#  10.60
#       state0: E = -2.033812422160  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#       state1: E = -1.725921492438  <S**2> = +0.00000000  <N> = 4.00000000  Fidelity = 0.000000  CPU Time =  0.05
#
# CONVERGED at beta=10.60.
# Final:
#       E[0-MSQITE] = -2.033812422160  (<S**2> = +0.00000)
#       E[1-MSQITE] = -1.725921492438  (<S**2> = +0.00000)
# ------------------------------------
# QITE Basis   0
#   Basis          Coef
# | 0001 > : +0.9669 +0.0000i
# | 0011 > : -0.1289 +0.0000i
# | 1100 > : -0.1225 +0.0000i
#
# QITE Basis   1
#   Basis          Coef
# | 0010 > : +0.9332 +0.0000i
# | 0011 > : -0.1992 +0.0000i
# | 0101 > : -0.1179 +0.0000i
# | 0111 > : +0.1076 +0.0000i
# | 1000 > : +0.1076 +0.0000i
# | 1010 > : -0.1179 +0.0000i
# | 1100 > : -0.1820 +0.0000i
#
#
# Coefficients:
#
#                0              1
#
#     0      0.9750150      0.2221389
#     1     -0.2221504      0.9750124
#
# ------------------------------------
#
#
# ###############################################
# #               MSQITE   states               #
# ###############################################
# State        : 0
# E            : -2.03381242
# <S**2>       : +0.00000
# Superposition:
#   Basis          Coef
# | 0001 > : +0.9391 +0.0000i
# | 0010 > : -0.2519 +0.0000i
# | 0111 > : -0.1083 +0.0000i
# | 1000 > : -0.1083 +0.0000i
#
#
# State        : 1
# E            : -1.72592149
# <S**2>       : +0.00000
# Superposition:
#   Basis          Coef
# | 0001 > : +0.2305 +0.0000i
# | 0010 > : +0.8997 +0.0000i
# | 0011 > : -0.2228 +0.0000i
# | 0101 > : -0.1144 +0.0000i
# | 1010 > : -0.1144 +0.0000i
# | 1100 > : -0.2046 +0.0000i
#
# ###############################################
