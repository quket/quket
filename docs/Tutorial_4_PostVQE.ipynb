# %% [markdown]
# # Tutorial (4): Post-VQE treatments
#
# Here we show some examples of post-VQE treatments.

# %% [markdown]
# [(0) Prepare and run UCCD](#(0)-Prepare-and-run-UCCD)
# [(1) VQD for excited state calculation](#(1)-VQD-for-excited-state-calculation)
# [(2) Nuclear gradients and geometry optimization](#(2)-Nuclear-gradients-and-geometry-optimization)
# [(3) Orbital optimization](#(3)-Orbital-optimization)

# %%
# import necessary modules
from quket import *
from quket.utils import *
import quket.config as cf

# %% [markdown]
# ## (0) Prepare and run UCCSD
# For this tutorial, first run SAUCCD-VQE

# %%
### Create QuketData for H2O ###
Q = create(basis="cc-pvdz", 
           ansatz="sauccgd", 
           n_orbitals =5, 
           n_electrons=6, 
           geometry = "O             ;\
                       H 1 1         ;\
                       H 1 1 2 110   ",
           taper_off = True,
           nroots = 2,
           qubitfci = True
        )
# Run UCCD
Q.run()
# Out:
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O     0.0000000    0.0000000    0.0000000
#   H     1.0000000    0.0000000    0.0000000
#   H    -0.3420201    0.0000000    0.9396926
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.024713570960     (Spin = 1   Ms = 0)
#             -75.622866608529     (Spin = 1   Ms = 0)
# E[HF]     = -76.020139776626     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# NBasis = 24
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# FCI in Qubits (tapered-off mapping)
# (FCI state : E = -76.02471357085764)
#    Basis           Coef
# | 000011 > : +0.9982 +0.0000i
#
# (FCI state : E = -75.62286626218061)
#    Basis           Coef
# | 000111 > : +0.6942 +0.0000i
# | 001010 > : -0.6940 +0.0000i
# | 001110 > : +0.1077 +0.0000i
#
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.020139776627  <S**2> = +0.000000  Fidelity = 0.996334  rho = 1
#       1: E[sauccgd] = -76.022752097784  <S**2> = +0.000000  Fidelity = 0.998335  Grad = 1.29e-01  CPU Time =    0.24040  (0.00 / step)
#       2: E[sauccgd] = -76.024032215438  <S**2> = +0.000000  Fidelity = 0.999502  Grad = 8.93e-02  CPU Time =    0.09407  (0.01 / step)
#       3: E[sauccgd] = -76.024439368210  <S**2> = +0.000000  Fidelity = 0.999766  Grad = 6.91e-02  CPU Time =    0.18145  (0.01 / step)
#       4: E[sauccgd] = -76.024570010255  <S**2> = +0.000000  Fidelity = 0.999901  Grad = 2.56e-02  CPU Time =    0.08981  (0.01 / step)
#       5: E[sauccgd] = -76.024596010604  <S**2> = +0.000000  Fidelity = 0.999924  Grad = 1.76e-02  CPU Time =    0.09087  (0.01 / step)
#       6: E[sauccgd] = -76.024626363783  <S**2> = +0.000000  Fidelity = 0.999949  Grad = 4.95e-03  CPU Time =    0.09345  (0.01 / step)
#       7: E[sauccgd] = -76.024629412247  <S**2> = +0.000000  Fidelity = 0.999955  Grad = 4.09e-03  CPU Time =    0.09406  (0.01 / step)
#       8: E[sauccgd] = -76.024633364870  <S**2> = +0.000000  Fidelity = 0.999959  Grad = 4.09e-03  CPU Time =    0.09257  (0.01 / step)
#       9: E[sauccgd] = -76.024638881777  <S**2> = +0.000000  Fidelity = 0.999962  Grad = 4.47e-03  CPU Time =    0.09139  (0.01 / step)
#      10: E[sauccgd] = -76.024664112042  <S**2> = +0.000000  Fidelity = 0.999972  Grad = 8.00e-03  CPU Time =    0.09117  (0.01 / step)
#      11: E[sauccgd] = -76.024687528058  <S**2> = +0.000000  Fidelity = 0.999982  Grad = 8.37e-03  CPU Time =    0.09208  (0.01 / step)
#      12: E[sauccgd] = -76.024694222047  <S**2> = +0.000000  Fidelity = 0.999983  Grad = 1.14e-02  CPU Time =    0.18187  (0.01 / step)
#      13: E[sauccgd] = -76.024706973647  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 3.21e-03  CPU Time =    0.09628  (0.01 / step)
#      14: E[sauccgd] = -76.024708861374  <S**2> = +0.000000  Fidelity = 0.999998  Grad = 9.59e-04  CPU Time =    0.09100  (0.01 / step)
#      15: E[sauccgd] = -76.024708878249  <S**2> = +0.000000  Fidelity = 0.999998  Grad = 2.15e-03  CPU Time =    0.09244  (0.01 / step)
#   Final: E[sauccgd] = -76.024708878249  <S**2> = +0.000000  Fidelity = 0.999998  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9982 +0.0000i
#
#
# VQE Done: CPU Time =          1.7205

# %% [markdown]
# ## (1) VQD for excited state calculation
# `vqd()` prepares for excited state calculation with variational quantum deflation (VQD).
# The previous VQE has to be converged: see
# ```python
#    Q.converge
# ```
# and the penalty parameter is set to the previous energy, `Q.energy`.
# It is also advisable to use an initial state that is approximately orthogonal to the previous states.
#
# #### First copy `Q` to a new `QuketData` instance.

# %%
VQD = Q.copy()

# %% [markdown]
# ### Point-group symmetry
# Due to the point-group symmetry C$2v$ of H$_2$O, the ground state possesses an A$_g$ symmetry.
# The first singlet excited state we aim for should have the same symmetry as the ground state.
# Otherwise, VQD makes no sense especially with qubits being tapered-off by point-group symmetry.
# To ensure the point-group symmetry of the VQD state, it is convenient to look at the MO symmetries.

# %%
VQD.print_mo_energy()
# Out:
# [Molecular Orbitals]
# ---+-------+------------+------------------
#  # |  Sym  |   energy   |     category
# ---+-------+------------+------------------
#  0 |   A1  |   -20.5544 | Frozen Core
#  1 |   A1  |    -1.3121 | Frozen Core
#  2 |   B1  |    -0.6862 | Active (occupied)
#  3 |   A1  |    -0.5477 | Active (occupied)
#  4 |   B2  |    -0.4881 | Active (occupied)
#  5 |   A1  |     0.1785 | Active (virtual)
#  6 |   B1  |     0.2493 | Active (virtual)
#  7 |   B1  |     0.7792 | Secondary
#  8 |   A1  |     0.7921 | Secondary
#  9 |   A1  |     1.1644 | Secondary
# 10 |   B2  |     1.2004 | Secondary
# 11 |   B1  |     1.2501 | Secondary
# 12 |   A2  |     1.4506 | Secondary
# 13 |   A1  |     1.4981 | Secondary
# 14 |   B2  |     1.6943 | Secondary
# 15 |   B1  |     1.8621 | Secondary
# 16 |   A1  |     1.8889 | Secondary
# 17 |   B1  |     2.3708 | Secondary
# 18 |   A1  |     2.3817 | Secondary
# 19 |   B2  |     3.2223 | Secondary
# 20 |   A2  |     3.3175 | Secondary
# 21 |   A1  |     3.4172 | Secondary
# 22 |   A1  |     3.8699 | Secondary
# 23 |   B1  |     4.0674 | Secondary
# ---+-------+------------+------------------

# %% [markdown]
# #### VQD setting with `vqd()`
# Based on the orbital symmetries above, the lowest excited state of $A_g$ is orbital `3` -> orbital `5`.
# To create a singlet state, a two-determinant initial state
# \begin{equation}
# \frac{1}{\sqrt{2}} \left( |0001111011\rangle - |0010110111\rangle\right)
# \end{equation}
# should be prepared.

# %%
VQD.vqd(det="1 * |0001111011> - 1 * |0010110111>")
# Out:
# Performing VQD for excited state 1
# Tapered-off initial state...
# pauli_list transformed.
# Tapered-off pauli list...
# VQD ready. Perform run().

# %% [markdown]
# #### Check the state.
# Note that because of `taper_off = True`, the initial state for VQE is also tapered-off.

# %%
print_state(VQD.init_state)
# Out:
#    Basis           Coef
# | 000111 > : +0.7071 +0.0000i
# | 001010 > : -0.7071 +0.0000i

# %% [markdown]
# #### Backtransform and check the state.
# A tapered state can be backtransformed to the original mapping by `transform_state()`.

# %%
test_state = VQD.transform_state(VQD.init_state, backtransform=True)
print_state(test_state)
# Out:
#      Basis             Coef
# | 0001111011 > : +0.7071 +0.0000i
# | 0010110111 > : -0.7071 +0.0000i

# %% [markdown]
# #### This is indeed $\frac{1}{\sqrt{2}} \left( |0001111011\rangle - |0010110111\rangle\right)$.
# ### Now run VQD.

# %%
VQD.run()
# Out:
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration:  +1.0000+0.0000j * |1111011> -1.0000+0.0000j * |10110111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -75.593113704590  <S**2> = +0.000000  Fidelity = 0.000176  rho = 1
#       1: E[sauccgd] = -75.591476707648  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 1.07e+00  CPU Time =    0.32777  (0.00 / step)
#       2: E[sauccgd] = -75.597543526679  <S**2> = +0.000000  Fidelity = 0.000004  Grad = 2.20e+00  CPU Time =    0.26213  (0.01 / step)
#       3: E[sauccgd] = -75.610505662114  <S**2> = +0.000000  Fidelity = 0.000019  Grad = 3.72e+00  CPU Time =    0.09006  (0.01 / step)
#       4: E[sauccgd] = -75.612692928151  <S**2> = +0.000000  Fidelity = 0.000002  Grad = 1.58e+00  CPU Time =    0.09394  (0.01 / step)
#       5: E[sauccgd] = -75.613407236313  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 3.88e-01  CPU Time =    0.09503  (0.01 / step)
#       6: E[sauccgd] = -75.613527881690  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 4.93e-01  CPU Time =    0.09134  (0.01 / step)
#       7: E[sauccgd] = -75.614114472980  <S**2> = +0.000000  Fidelity = 0.000003  Grad = 8.88e-01  CPU Time =    0.09251  (0.01 / step)
#       8: E[sauccgd] = -75.615353152721  <S**2> = +0.000000  Fidelity = 0.000006  Grad = 1.42e+00  CPU Time =    0.09258  (0.01 / step)
#       9: E[sauccgd] = -75.617673352447  <S**2> = +0.000001  Fidelity = 0.000008  Grad = 1.91e+00  CPU Time =    0.09193  (0.01 / step)
#      10: E[sauccgd] = -75.620233729454  <S**2> = +0.000005  Fidelity = 0.000007  Grad = 1.85e+00  CPU Time =    0.09356  (0.01 / step)
#      11: E[sauccgd] = -75.622388074679  <S**2> = +0.000009  Fidelity = 0.000000  Grad = 3.65e-01  CPU Time =    0.09182  (0.01 / step)
#      12: E[sauccgd] = -75.622633560947  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 3.58e-01  CPU Time =    0.09467  (0.01 / step)
#      13: E[sauccgd] = -75.622666163444  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 1.74e-01  CPU Time =    0.09272  (0.01 / step)
#      14: E[sauccgd] = -75.622669074874  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 1.33e-01  CPU Time =    0.09439  (0.01 / step)
#      15: E[sauccgd] = -75.622697513072  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 6.57e-02  CPU Time =    0.09260  (0.01 / step)
#      16: E[sauccgd] = -75.622745769039  <S**2> = +0.000007  Fidelity = 0.000000  Grad = 1.89e-01  CPU Time =    0.09234  (0.01 / step)
#      17: E[sauccgd] = -75.622815128884  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 2.25e-01  CPU Time =    0.09379  (0.01 / step)
#      18: E[sauccgd] = -75.622841560183  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.33e-01  CPU Time =    0.09427  (0.01 / step)
#      19: E[sauccgd] = -75.622841669059  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.61e-02  CPU Time =    0.09080  (0.01 / step)
#      20: E[sauccgd] = -75.622842802988  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 6.08e-03  CPU Time =    0.09356  (0.01 / step)
#      21: E[sauccgd] = -75.622842982930  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 4.59e-03  CPU Time =    0.09297  (0.01 / step)
#      22: E[sauccgd] = -75.622843393920  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 8.46e-03  CPU Time =    0.09170  (0.01 / step)
#      23: E[sauccgd] = -75.622843901564  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.29e-02  CPU Time =    0.09635  (0.01 / step)
#      24: E[sauccgd] = -75.622844347325  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 8.69e-03  CPU Time =    0.09332  (0.01 / step)
#      25: E[sauccgd] = -75.622844435283  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.55e-02  CPU Time =    0.17840  (0.01 / step)
#   Final: E[1-sauccgd] = -75.622844435283  <S**2> = +0.000006  Fidelity = 0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000111 > : +0.6928 +0.0000i
# | 001010 > : -0.6953 +0.0000i
# | 001110 > : +0.1076 +0.0000i
#
#
# VQE Done: CPU Time =          2.8227

# %% [markdown]
# #### Note that VQD, especially with generalized UCC, is a highly nonlinear problem and may take a long time to converge.
# ### Check the energy

# %%
print("FCI energies:        ", VQD.fci_energy)
print("SA-UCCGD VQE energy:  ", VQD.lower_states[0]['energy'])
print("SA-UCCGD VQD energy:  ", VQD.energy)
# Out:
# FCI energies:         [-76.02471357095992 -75.62286660852946]
# SA-UCCGD VQE energy:   -76.02470887824943
# SA-UCCGD VQD energy:   -75.62284443528321

# %% [markdown]
# ## (2) Nuclear gradients and geometry optimization
# Nuclear gradient calculation and geometry optimization can be run with `grad()` and `opt()`.
# If qubits are tapered-off, states should be backtransformed because computing reduced density matrices in the reduced mapping is currently not supported.

# %%
Grad = Q.copy()
# Compute nuclear gradients
Grad.taper_off(backtransform=True)
Grad.grad()
# Out:
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0177772    0.0000000   -0.0253885
#   H     0.0450532   -0.0000000   -0.0126284
#   H    -0.0272759   -0.0000000    0.0380170
# *******************************************

# %% [markdown]
# ### Geometry optimization requires the installation of `pyberny`

# %%
OPT = Q.copy()
# Geometry optimization
OPT.taper_off()
OPT.opt()
# Out:
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# Current pauli_list is already tapered-off. No transformation done
# Current theta_list is already tapered-off. No transformation done
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0177772    0.0000000   -0.0253885
#   H     0.0450532   -0.0000000   -0.0126284
#   H    -0.0272759   -0.0000000    0.0380170
# *******************************************
#
# """""""""""""""""""
#      Cycle 0
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0076740    0.0000000   -0.0109596
#   H     0.9435717    0.0000000    0.0476781
#   H    -0.2779178    0.0000000    0.9029742
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030303476378     (Spin = 1   Ms = 0)
#             -75.596953886112     (Spin = 1   Ms = 0)
# E[HF]     = -76.026899177282     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028835013686  <S**2> = +0.000000  Grad = 1.14e-01  CPU Time =    0.23292  (0.00 / step)
#       2: E[sauccgd] = -76.029799060813  <S**2> = +0.000000  Grad = 7.74e-02  CPU Time =    0.09194  (0.01 / step)
#       3: E[sauccgd] = -76.030109459397  <S**2> = +0.000000  Grad = 6.25e-02  CPU Time =    0.17965  (0.01 / step)
#       4: E[sauccgd] = -76.030209530795  <S**2> = +0.000000  Grad = 2.38e-02  CPU Time =    0.09247  (0.01 / step)
#       5: E[sauccgd] = -76.030227919491  <S**2> = +0.000000  Grad = 1.43e-02  CPU Time =    0.09317  (0.01 / step)
#       6: E[sauccgd] = -76.030245293863  <S**2> = +0.000000  Grad = 5.40e-03  CPU Time =    0.10269  (0.01 / step)
#       7: E[sauccgd] = -76.030247599319  <S**2> = +0.000000  Grad = 2.82e-03  CPU Time =    0.09437  (0.01 / step)
#       8: E[sauccgd] = -76.030249021918  <S**2> = +0.000000  Grad = 2.51e-03  CPU Time =    0.09309  (0.01 / step)
#       9: E[sauccgd] = -76.030250636066  <S**2> = +0.000000  Grad = 2.92e-03  CPU Time =    0.09271  (0.01 / step)
#      10: E[sauccgd] = -76.030253796950  <S**2> = +0.000000  Grad = 3.82e-03  CPU Time =    0.09407  (0.01 / step)
#      11: E[sauccgd] = -76.030261307842  <S**2> = +0.000000  Grad = 6.14e-03  CPU Time =    0.09262  (0.01 / step)
#      12: E[sauccgd] = -76.030274019174  <S**2> = +0.000000  Grad = 8.08e-03  CPU Time =    0.09276  (0.01 / step)
#      13: E[sauccgd] = -76.030289245738  <S**2> = +0.000000  Grad = 8.64e-03  CPU Time =    0.09035  (0.01 / step)
#      14: E[sauccgd] = -76.030296368753  <S**2> = +0.000000  Grad = 1.02e-02  CPU Time =    0.09152  (0.01 / step)
#      15: E[sauccgd] = -76.030299374436  <S**2> = +0.000000  Grad = 6.84e-03  CPU Time =    0.09455  (0.01 / step)
#      16: E[sauccgd] = -76.030300221345  <S**2> = +0.000000  Grad = 7.21e-04  CPU Time =    0.09185  (0.01 / step)
#      17: E[sauccgd] = -76.030300243625  <S**2> = +0.000000  Grad = 4.14e-04  CPU Time =    0.09383  (0.01 / step)
#   Final: E[sauccgd] = -76.030300243625  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0009884   -0.0000000   -0.0014116
#   H    -0.0004062    0.0000000    0.0013363
#   H     0.0013946    0.0000000    0.0000754
# *******************************************
#
# """""""""""""""""""
#      Cycle 1
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0059431    0.0000000   -0.0084876
#   H     0.9458339    0.0000000    0.0442520
#   H    -0.2819109    0.0000000    0.9039282
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030319533945     (Spin = 1   Ms = 0)
#             -75.598326847387     (Spin = 1   Ms = 0)
# E[HF]     = -76.026936384182     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028862077560  <S**2> = +0.000000  Grad = 1.14e-01  CPU Time =    0.23266  (0.00 / step)
#       2: E[sauccgd] = -76.029822612460  <S**2> = +0.000000  Grad = 7.70e-02  CPU Time =    0.09281  (0.01 / step)
#       3: E[sauccgd] = -76.030127277626  <S**2> = +0.000000  Grad = 6.21e-02  CPU Time =    0.17691  (0.01 / step)
#       4: E[sauccgd] = -76.030226582358  <S**2> = +0.000000  Grad = 2.34e-02  CPU Time =    0.09188  (0.01 / step)
#       5: E[sauccgd] = -76.030244694806  <S**2> = +0.000000  Grad = 1.43e-02  CPU Time =    0.09234  (0.01 / step)
#       6: E[sauccgd] = -76.030262254127  <S**2> = +0.000000  Grad = 5.06e-03  CPU Time =    0.09583  (0.01 / step)
#       7: E[sauccgd] = -76.030264410182  <S**2> = +0.000000  Grad = 2.76e-03  CPU Time =    0.09009  (0.01 / step)
#       8: E[sauccgd] = -76.030265940538  <S**2> = +0.000000  Grad = 2.47e-03  CPU Time =    0.09191  (0.01 / step)
#       9: E[sauccgd] = -76.030267538297  <S**2> = +0.000000  Grad = 2.87e-03  CPU Time =    0.09247  (0.01 / step)
#      10: E[sauccgd] = -76.030271119588  <S**2> = +0.000000  Grad = 3.94e-03  CPU Time =    0.09233  (0.01 / step)
#      11: E[sauccgd] = -76.030278832107  <S**2> = +0.000000  Grad = 6.58e-03  CPU Time =    0.09185  (0.01 / step)
#      12: E[sauccgd] = -76.030291577947  <S**2> = +0.000000  Grad = 7.67e-03  CPU Time =    0.09482  (0.01 / step)
#      13: E[sauccgd] = -76.030306675446  <S**2> = +0.000000  Grad = 9.58e-03  CPU Time =    0.09170  (0.01 / step)
#      14: E[sauccgd] = -76.030314474203  <S**2> = +0.000000  Grad = 5.77e-03  CPU Time =    0.09111  (0.01 / step)
#      15: E[sauccgd] = -76.030315331280  <S**2> = +0.000000  Grad = 7.59e-03  CPU Time =    0.09347  (0.01 / step)
#      16: E[sauccgd] = -76.030316314232  <S**2> = +0.000000  Grad = 6.33e-04  CPU Time =    0.09152  (0.01 / step)
#      17: E[sauccgd] = -76.030316335031  <S**2> = +0.000000  Grad = 4.03e-04  CPU Time =    0.09517  (0.01 / step)
#   Final: E[sauccgd] = -76.030316335031  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0002999    0.0000000   -0.0004283
#   H     0.0003080   -0.0000000    0.0001035
#   H    -0.0000080   -0.0000000    0.0003248
# *******************************************
#
# """""""""""""""""""
#      Cycle 2
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0056954    0.0000000   -0.0081339
#   H     0.9457480    0.0000000    0.0440487
#   H    -0.2820726    0.0000000    0.9037779
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030319776873     (Spin = 1   Ms = 0)
#             -75.598306322278     (Spin = 1   Ms = 0)
# E[HF]     = -76.026948785366     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Tapering-Off Results:
# List of Tapered-off Qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028867804721  <S**2> = +0.000000  Grad = 1.13e-01  CPU Time =    0.23212  (0.00 / step)
#       2: E[sauccgd] = -76.029825462856  <S**2> = +0.000000  Grad = 7.68e-02  CPU Time =    0.09168  (0.01 / step)
#       3: E[sauccgd] = -76.030128399234  <S**2> = +0.000000  Grad = 6.20e-02  CPU Time =    0.17927  (0.01 / step)
#       4: E[sauccgd] = -76.030227340733  <S**2> = +0.000000  Grad = 2.33e-02  CPU Time =    0.09288  (0.01 / step)
#       5: E[sauccgd] = -76.030245354078  <S**2> = +0.000000  Grad = 1.42e-02  CPU Time =    0.09275  (0.01 / step)
#       6: E[sauccgd] = -76.030262857482  <S**2> = +0.000000  Grad = 5.02e-03  CPU Time =    0.09463  (0.01 / step)
#       7: E[sauccgd] = -76.030264988112  <S**2> = +0.000000  Grad = 2.74e-03  CPU Time =    0.09236  (0.01 / step)
#       8: E[sauccgd] = -76.030266522730  <S**2> = +0.000000  Grad = 2.46e-03  CPU Time =    0.09315  (0.01 / step)
#       9: E[sauccgd] = -76.030268105986  <S**2> = +0.000000  Grad = 2.85e-03  CPU Time =    0.09334  (0.01 / step)
#      10: E[sauccgd] = -76.030271715773  <S**2> = +0.000000  Grad = 3.94e-03  CPU Time =    0.09391  (0.01 / step)
#      11: E[sauccgd] = -76.030279382397  <S**2> = +0.000000  Grad = 6.62e-03  CPU Time =    0.09340  (0.01 / step)
#      12: E[sauccgd] = -76.030292057998  <S**2> = +0.000000  Grad = 7.61e-03  CPU Time =    0.09268  (0.01 / step)
#      13: E[sauccgd] = -76.030307060849  <S**2> = +0.000000  Grad = 9.82e-03  CPU Time =    0.09136  (0.01 / step)
#      14: E[sauccgd] = -76.030314895136  <S**2> = +0.000000  Grad = 5.19e-03  CPU Time =    0.09292  (0.01 / step)
#      15: E[sauccgd] = -76.030315721973  <S**2> = +0.000000  Grad = 7.14e-03  CPU Time =    0.09373  (0.01 / step)
#      16: E[sauccgd] = -76.030316574589  <S**2> = +0.000000  Grad = 6.44e-04  CPU Time =    0.09379  (0.01 / step)
#      17: E[sauccgd] = -76.030316595800  <S**2> = +0.000000  Grad = 3.91e-04  CPU Time =    0.09452  (0.01 / step)
#   Final: E[sauccgd] = -76.030316595800  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O     0.0000245   -0.0000000    0.0000350
#   H    -0.0000337    0.0000000   -0.0000025
#   H     0.0000092    0.0000000   -0.0000325
# *******************************************
#
# Geometry Optimization Converged in 2 cycles
#
# *** Geometry ******************************
#   O    -0.0056954    0.0000000   -0.0081339
#   H     0.9457480    0.0000000    0.0440487
#   H    -0.2820726    0.0000000    0.9037779
# *******************************************

# %% [markdown]
# ## (3) Orbital optimization
# `oo()` performs orbital optimization.
# It assumes the method is VQE, but works for most ansatze.

# %%
# This example provides oo-SAUCCD
OO = Q.copy()
OO.oo()
# Out:
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 1
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.03256249108865558  (C0 = -0.5420956622737526)
# Golden Section done in 2
#
#
#
# ||g|| = 0.034805231679487805 ---> Updated with scaling factor 0.8594235253127366
#
#
# Next energy estimation:  -76.05014212152369
# FCI in Qubits
# (FCI state : E = -76.06936955694405)
#      Basis             Coef
# | 0000111111 > : +0.9895 +0.0000i
#
# (FCI state : E = -75.07183615082062)
#      Basis             Coef
# | 0001111011 > : +0.5650 +0.0000i
# | 0010110111 > : -0.5648 +0.0000i
# | 0100111110 > : -0.4184 +0.0000i
# | 1000111101 > : +0.4183 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.050142121525  <S**2> = +0.000000  Fidelity = 0.991760  rho = 1
#       1: E[sauccgd] = -76.060149028492  <S**2> = +0.000000  Fidelity = 0.995145  Grad = 3.96e-01  CPU Time =    0.28292  (0.01 / step)
#       2: E[sauccgd] = -76.063923377376  <S**2> = +0.000000  Fidelity = 0.997325  Grad = 2.22e-01  CPU Time =    0.09531  (0.01 / step)
#       3: E[sauccgd] = -76.067163471732  <S**2> = +0.000000  Fidelity = 0.999152  Grad = 1.58e-01  CPU Time =    0.09336  (0.01 / step)
#       4: E[sauccgd] = -76.067569188788  <S**2> = +0.000000  Fidelity = 0.999382  Grad = 1.26e-01  CPU Time =    0.18424  (0.01 / step)
#       5: E[sauccgd] = -76.067847029269  <S**2> = +0.000000  Fidelity = 0.999513  Grad = 8.84e-02  CPU Time =    0.09471  (0.01 / step)
#       6: E[sauccgd] = -76.068278933038  <S**2> = +0.000000  Fidelity = 0.999680  Grad = 6.32e-02  CPU Time =    0.09501  (0.01 / step)
#       7: E[sauccgd] = -76.068451286986  <S**2> = +0.000000  Fidelity = 0.999685  Grad = 9.82e-02  CPU Time =    0.09599  (0.01 / step)
#       8: E[sauccgd] = -76.068612904976  <S**2> = +0.000000  Fidelity = 0.999766  Grad = 5.37e-02  CPU Time =    0.09354  (0.01 / step)
#       9: E[sauccgd] = -76.068788482019  <S**2> = +0.000000  Fidelity = 0.999808  Grad = 5.35e-02  CPU Time =    0.09313  (0.01 / step)
#      10: E[sauccgd] = -76.068986315824  <S**2> = +0.000000  Fidelity = 0.999852  Grad = 7.00e-02  CPU Time =    0.09381  (0.01 / step)
#      11: E[sauccgd] = -76.069234392283  <S**2> = +0.000000  Fidelity = 0.999938  Grad = 5.04e-02  CPU Time =    0.09290  (0.01 / step)
#      12: E[sauccgd] = -76.069300772763  <S**2> = +0.000000  Fidelity = 0.999977  Grad = 1.59e-02  CPU Time =    0.09392  (0.01 / step)
#      13: E[sauccgd] = -76.069304824216  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 4.71e-03  CPU Time =    0.09448  (0.01 / step)
#      14: E[sauccgd] = -76.069306256555  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 6.35e-03  CPU Time =    0.09446  (0.01 / step)
#      15: E[sauccgd] = -76.069307936789  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 1.05e-02  CPU Time =    0.09391  (0.01 / step)
#      16: E[sauccgd] = -76.069311717699  <S**2> = +0.000000  Fidelity = 0.999981  Grad = 1.62e-02  CPU Time =    0.09624  (0.01 / step)
#      17: E[sauccgd] = -76.069318413812  <S**2> = +0.000000  Fidelity = 0.999982  Grad = 2.04e-02  CPU Time =    0.09163  (0.01 / step)
#      18: E[sauccgd] = -76.069330942109  <S**2> = +0.000000  Fidelity = 0.999984  Grad = 2.29e-02  CPU Time =    0.09350  (0.01 / step)
#      19: E[sauccgd] = -76.069338404493  <S**2> = +0.000000  Fidelity = 0.999987  Grad = 2.62e-02  CPU Time =    0.17868  (0.01 / step)
#      20: E[sauccgd] = -76.069349069034  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 1.22e-02  CPU Time =    0.09604  (0.01 / step)
#      21: E[sauccgd] = -76.069353626564  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 3.33e-03  CPU Time =    0.09571  (0.01 / step)
#      22: E[sauccgd] = -76.069354070522  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 3.02e-03  CPU Time =    0.09222  (0.01 / step)
#      23: E[sauccgd] = -76.069354454176  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.60e-03  CPU Time =    0.09404  (0.01 / step)
#      24: E[sauccgd] = -76.069354576744  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 8.15e-04  CPU Time =    0.09336  (0.01 / step)
#      25: E[sauccgd] = -76.069354604467  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 8.83e-04  CPU Time =    0.09490  (0.01 / step)
#   Final: E[sauccgd] = -76.069354604467  <S**2> = +0.000000  Fidelity = 0.999995  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9895 +0.0000i
#
#
# VQE Done: CPU Time =          2.7257
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 2
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.009984340965328074  (C0 = 0.8955185301639553)
# Golden Section done in 0
#
#
#
# deltaE = -0.04464572621758123    ||g|| = 0.05632613279696532 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07397154107913
# FCI in Qubits
# (FCI state : E = -76.0745728224178)
#      Basis             Coef
# | 0000111111 > : +0.9880 +0.0000i
#
# (FCI state : E = -75.03515900675647)
#      Basis             Coef
# | 0001111011 > : +0.4750 +0.0000i
# | 0010110111 > : -0.4750 +0.0000i
# | 0100111110 > : -0.5125 +0.0000i
# | 1000111101 > : +0.5126 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.073971541079  <S**2> = +0.000000  Fidelity = 0.999682  rho = 1
#       1: E[sauccgd] = -76.074291198370  <S**2> = +0.000000  Fidelity = 0.999867  Grad = 6.77e-02  CPU Time =    0.28486  (0.01 / step)
#       2: E[sauccgd] = -76.074455866573  <S**2> = +0.000000  Fidelity = 0.999947  Grad = 4.14e-02  CPU Time =    0.09204  (0.01 / step)
#       3: E[sauccgd] = -76.074482501772  <S**2> = +0.000000  Fidelity = 0.999944  Grad = 7.34e-02  CPU Time =    0.09360  (0.01 / step)
#       4: E[sauccgd] = -76.074541477482  <S**2> = +0.000000  Fidelity = 0.999988  Grad = 1.91e-02  CPU Time =    0.09503  (0.01 / step)
#       5: E[sauccgd] = -76.074547094905  <S**2> = +0.000000  Fidelity = 0.999991  Grad = 1.08e-02  CPU Time =    0.09022  (0.01 / step)
#       6: E[sauccgd] = -76.074553179968  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 6.00e-03  CPU Time =    0.09179  (0.01 / step)
#       7: E[sauccgd] = -76.074555582133  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.79e-03  CPU Time =    0.09574  (0.01 / step)
#       8: E[sauccgd] = -76.074555953549  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.46e-03  CPU Time =    0.09411  (0.01 / step)
#       9: E[sauccgd] = -76.074557014226  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 2.16e-03  CPU Time =    0.09365  (0.01 / step)
#      10: E[sauccgd] = -76.074557320332  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 4.94e-03  CPU Time =    0.09386  (0.01 / step)
#      11: E[sauccgd] = -76.074557849779  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.98e-03  CPU Time =    0.09473  (0.01 / step)
#      12: E[sauccgd] = -76.074558243986  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.49e-03  CPU Time =    0.09449  (0.01 / step)
#      13: E[sauccgd] = -76.074558614947  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.71e-03  CPU Time =    0.09461  (0.01 / step)
#      14: E[sauccgd] = -76.074559360898  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.81e-03  CPU Time =    0.09379  (0.01 / step)
#      15: E[sauccgd] = -76.074559809997  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 4.22e-03  CPU Time =    0.18102  (0.01 / step)
#      16: E[sauccgd] = -76.074560769615  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.76e-03  CPU Time =    0.09451  (0.01 / step)
#      17: E[sauccgd] = -76.074560895095  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 3.55e-03  CPU Time =    0.09448  (0.01 / step)
#      18: E[sauccgd] = -76.074561060640  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 9.87e-04  CPU Time =    0.09403  (0.01 / step)
#      19: E[sauccgd] = -76.074561087054  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 6.94e-04  CPU Time =    0.09385  (0.01 / step)
#   Final: E[sauccgd] = -76.074561087054  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9880 +0.0000i
#
#
# VQE Done: CPU Time =          2.0679
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 3
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.0006187306659302077  (C0 = 0.9975033819381484)
# Golden Section done in 0
#
#
#
# deltaE = -0.005206482587183814    ||g|| = 0.017184411826440486 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07485161508913
# FCI in Qubits
# (FCI state : E = -76.07488543212352)
#      Basis             Coef
# | 0000111111 > : +0.9876 +0.0000i
#
# (FCI state : E = -75.05088079807068)
#      Basis             Coef
# | 0001111011 > : +0.4589 +0.0000i
# | 0010110111 > : -0.4588 +0.0000i
# | 0100111110 > : -0.5256 +0.0000i
# | 1000111101 > : +0.5257 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074851615089  <S**2> = +0.000000  Fidelity = 0.999985  rho = 1
#       1: E[sauccgd] = -76.074864269546  <S**2> = +0.000000  Fidelity = 0.999992  Grad = 1.22e-02  CPU Time =    0.28167  (0.01 / step)
#       2: E[sauccgd] = -76.074871313676  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 6.63e-03  CPU Time =    0.09425  (0.01 / step)
#       3: E[sauccgd] = -76.074872696351  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 8.19e-03  CPU Time =    0.17888  (0.01 / step)
#       4: E[sauccgd] = -76.074873821744  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 3.00e-03  CPU Time =    0.09200  (0.01 / step)
#       5: E[sauccgd] = -76.074874103981  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.06e-03  CPU Time =    0.09274  (0.01 / step)
#       6: E[sauccgd] = -76.074874318395  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.34e-03  CPU Time =    0.09607  (0.01 / step)
#       7: E[sauccgd] = -76.074874421087  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.24e-03  CPU Time =    0.09059  (0.01 / step)
#       8: E[sauccgd] = -76.074874463541  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.22e-03  CPU Time =    0.09211  (0.01 / step)
#   Final: E[sauccgd] = -76.074874463541  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9876 +0.0000i
#
#
# VQE Done: CPU Time =          1.0257
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 4
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -7.552819547295474e-05  (C0 = 0.9996897595591716)
# Golden Section done in 0
#
#
#
# deltaE = -0.00031337648687213004    ||g|| = 0.005725565142761911 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.0749098707997
# FCI in Qubits
# (FCI state : E = -76.07492404019037)
#      Basis             Coef
# | 0000111111 > : +0.9875 +0.0000i
#
# (FCI state : E = -75.05778355286662)
#      Basis             Coef
# | 0001111011 > : +0.4548 +0.0000i
# | 0010110111 > : -0.4550 +0.0000i
# | 0011111100 > : -0.1033 +0.0000i
# | 0100111110 > : -0.5284 +0.0000i
# | 1000111101 > : +0.5285 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074909870799  <S**2> = +0.000000  Fidelity = 0.999995  rho = 1
#       1: E[sauccgd] = -76.074911646628  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 4.61e-03  CPU Time =    0.29756  (0.01 / step)
#       2: E[sauccgd] = -76.074912654720  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.60e-03  CPU Time =    0.09360  (0.01 / step)
#       3: E[sauccgd] = -76.074913179621  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.26e-03  CPU Time =    0.09337  (0.01 / step)
#       4: E[sauccgd] = -76.074913274730  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.18e-03  CPU Time =    0.18055  (0.01 / step)
#       5: E[sauccgd] = -76.074913324159  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 9.80e-04  CPU Time =    0.09376  (0.01 / step)
#   Final: E[sauccgd] = -76.074913324159  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9875 +0.0000i
#
#
# VQE Done: CPU Time =          0.7662
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 5
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -1.0399141500646991e-05  (C0 = 0.999956753958171)
# Golden Section done in 0
#
#
#
# deltaE = -3.8860618005287506e-05    ||g|| = 0.002077665482271029 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07491819842645
# FCI in Qubits
# (FCI state : E = -76.074929316756)
#      Basis             Coef
# | 0000111111 > : +0.9875 +0.0000i
#
# (FCI state : E = -75.0606956734407)
#      Basis             Coef
# | 0001111011 > : +0.4547 +0.0000i
# | 0010110111 > : -0.4548 +0.0000i
# | 0011111100 > : -0.1044 +0.0000i
# | 0100111110 > : -0.5282 +0.0000i
# | 1000111101 > : +0.5283 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074918198426  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074918431516  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.89e-03  CPU Time =    0.28590  (0.01 / step)
#       2: E[sauccgd] = -76.074918568542  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.44e-03  CPU Time =    0.09569  (0.01 / step)
#       3: E[sauccgd] = -76.074918657761  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 3.17e-03  CPU Time =    0.09376  (0.01 / step)
#       4: E[sauccgd] = -76.074918778439  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.29e-03  CPU Time =    0.09418  (0.01 / step)
#       5: E[sauccgd] = -76.074918812769  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.04e-03  CPU Time =    0.09280  (0.01 / step)
#   Final: E[sauccgd] = -76.074918812769  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.6699
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 6
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -1.5171382416610287e-06  (C0 = 0.9999936300854184)
# Golden Section done in 0
#
#
#
# deltaE = -5.488609460257976e-06    ||g|| = 0.0007607781557768204 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07491952389564
# FCI in Qubits
# (FCI state : E = -76.07493006384212)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.06186940821611)
#      Basis             Coef
# | 0001111011 > : +0.4548 +0.0000i
# | 0010110111 > : -0.4548 +0.0000i
# | 0011111100 > : -0.1051 +0.0000i
# | 0100111110 > : -0.5282 +0.0000i
# | 1000111101 > : +0.5282 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074919523895  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074919548405  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.95e-03  CPU Time =    0.30967  (0.01 / step)
#   Final: E[sauccgd] = -76.074919548405  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.3177
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 7
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Warning: Too small C0 in AH : -4.132076632058071e-06
# This usually means the Hessian is not positive semi-definite and there is a lower state.
# Target lowest eigenvalue of augmented Hessian:  -0.0002370729832016551  (C0 = 1.0)
# Golden Section done in 4
#
#
#
# deltaE = -7.356364335464605e-07    ||g|| = 0.0007566067988820825 ---> Updated with scaling factor 0.9012195928133675
#
#
# Next energy estimation:  -76.07497108038585
# FCI in Qubits
# (FCI state : E = -76.07524947244978)
#      Basis             Coef
# | 0000111111 > : +0.9875 +0.0000i
#
# (FCI state : E = -75.05882453311189)
#      Basis             Coef
# | 0001111011 > : +0.4481 +0.0000i
# | 0010110111 > : -0.4481 +0.0000i
# | 0011111100 > : -0.1063 +0.0000i
# | 0100111110 > : -0.5374 +0.0000i
# | 1000111101 > : +0.5375 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074971080386  <S**2> = +0.000000  Fidelity = 0.999882  rho = 1
#       1: E[sauccgd] = -76.075219269128  <S**2> = +0.000000  Fidelity = 0.999988  Grad = 2.23e-02  CPU Time =    0.29009  (0.01 / step)
#       2: E[sauccgd] = -76.075227561980  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 9.46e-03  CPU Time =    0.17830  (0.01 / step)
#       3: E[sauccgd] = -76.075232069211  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 2.37e-03  CPU Time =    0.09615  (0.01 / step)
#       4: E[sauccgd] = -76.075232209822  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 4.76e-03  CPU Time =    0.09444  (0.01 / step)
#       5: E[sauccgd] = -76.075232442934  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.75e-03  CPU Time =    0.09367  (0.01 / step)
#       6: E[sauccgd] = -76.075232534210  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 8.35e-04  CPU Time =    0.09423  (0.01 / step)
#       7: E[sauccgd] = -76.075232558845  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 4.52e-04  CPU Time =    0.09103  (0.01 / step)
#   Final: E[sauccgd] = -76.075232558845  <S**2> = +0.000000  Fidelity = 0.999995  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9875 +0.0000i
#
#
# VQE Done: CPU Time =          0.9455
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 8
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.0007297004927984054  (C0 = 0.8016665914149294)
# Golden Section done in 0
#
#
#
# deltaE = -0.0003130104398110234    ||g|| = 0.007425266212164559 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07559312112082
# FCI in Qubits
# (FCI state : E = -76.0756493902667)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.0718043378584)
#      Basis             Coef
# | 0001111011 > : +0.4523 +0.0000i
# | 0010110111 > : -0.4524 +0.0000i
# | 0011111100 > : -0.1033 +0.0000i
# | 0100111110 > : -0.5341 +0.0000i
# | 1000111101 > : +0.5340 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075593121121  <S**2> = +0.000000  Fidelity = 0.999982  rho = 1
#       1: E[sauccgd] = -76.075617912151  <S**2> = +0.000000  Fidelity = 0.999990  Grad = 1.68e-02  CPU Time =    0.28036  (0.01 / step)
#       2: E[sauccgd] = -76.075623708559  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 5.60e-03  CPU Time =    0.17925  (0.01 / step)
#       3: E[sauccgd] = -76.075624279252  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.39e-03  CPU Time =    0.09509  (0.01 / step)
#       4: E[sauccgd] = -76.075624306734  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.21e-03  CPU Time =    0.09042  (0.01 / step)
#   Final: E[sauccgd] = -76.075624306734  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.6525
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 9
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -5.647253739412191e-05  (C0 = 0.9938458567971977)
# Golden Section done in 0
#
#
#
# deltaE = -0.00039174788959428497    ||g|| = 0.0036453692123842103 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.0756510639143
# FCI in Qubits
# (FCI state : E = -76.07567671028808)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.07092695363313)
#      Basis             Coef
# | 0001111011 > : +0.4466 +0.0000i
# | 0010110111 > : -0.4463 +0.0000i
# | 0011111100 > : -0.1036 +0.0000i
# | 0100111110 > : -0.5390 +0.0000i
# | 1000111101 > : +0.5390 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075651063915  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075651220306  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.65e-03  CPU Time =    0.28131  (0.01 / step)
#       2: E[sauccgd] = -76.075651316577  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.43e-03  CPU Time =    0.09497  (0.01 / step)
#       3: E[sauccgd] = -76.075651365243  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 5.62e-04  CPU Time =    0.09277  (0.01 / step)
#   Final: E[sauccgd] = -76.075651365243  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.4764
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 10
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -4.610069100202575e-06  (C0 = 0.9994886111604712)
# Golden Section done in 0
#
#
#
# deltaE = -2.7058508891286692e-05    ||g|| = 0.0009942491876890932 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07565353104432
# FCI in Qubits
# (FCI state : E = -76.07567895853047)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.07047408569527)
#      Basis             Coef
# | 0001111011 > : +0.4449 +0.0000i
# | 0010110111 > : -0.4449 +0.0000i
# | 0011111100 > : -0.1040 +0.0000i
# | 0100111110 > : -0.5402 +0.0000i
# | 1000111101 > : +0.5402 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075653531044  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075653549857  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 7.40e-04  CPU Time =    0.28024  (0.01 / step)
#   Final: E[sauccgd] = -76.075653549857  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2881
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 11
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -3.3882511103224053e-07  (C0 = 0.9999659941365372)
# Golden Section done in 0
#
#
#
# deltaE = -2.1846133648750765e-06    ||g|| = 0.0002907391704762508 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07565370876458
# FCI in Qubits
# (FCI state : E = -76.0756791363824)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.0703120794382)
#      Basis             Coef
# | 0001111011 > : +0.4440 +0.0000i
# | 0010110111 > : -0.4440 +0.0000i
# | 0011111100 > : -0.1041 +0.0000i
# | 0100111110 > : -0.5409 +0.0000i
# | 1000111101 > : +0.5409 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075653708764  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075653723647  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 7.21e-04  CPU Time =    0.28207  (0.01 / step)
#   Final: E[sauccgd] = -76.075653723647  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2901
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 12
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -2.802078841100384e-08  (C0 = 0.9999978285526382)
# Golden Section done in 0
#
#
#
# deltaE = -1.7379038297349325e-07    ||g|| = 0.0002129723704308054 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07565373678308
# FCI in Qubits
# (FCI state : E = -76.07567915881762)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.07031577173677)
#      Basis             Coef
# | 0001111011 > : +0.4440 +0.0000i
# | 0010110111 > : -0.4439 +0.0000i
# | 0011111100 > : -0.1042 +0.0000i
# | 0100111110 > : -0.5408 +0.0000i
# | 1000111101 > : +0.5411 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075653736783  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075653745084  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 5.17e-04  CPU Time =    0.28196  (0.01 / step)
#   Final: E[sauccgd] = -76.075653745084  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2899
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 13
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -7.772358870686188e-09  (C0 = 0.9999998356466989)
# Golden Section done in 0
#
#
#
# deltaE = -2.1436719066514343e-08    ||g|| = 0.00010770103339067027 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07565374872681
# FCI in Qubits
# (FCI state : E = -76.0756791626145)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.0702728227685)
#      Basis             Coef
# | 0001111011 > : +0.4436 +0.0000i
# | 0010110111 > : -0.4435 +0.0000i
# | 0011111100 > : -0.1040 +0.0000i
# | 0100111110 > : -0.5414 +0.0000i
# | 1000111101 > : +0.5412 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075653748727  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075653752486  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 6.71e-04  CPU Time =    0.28259  (0.01 / step)
#   Final: E[sauccgd] = -76.075653752486  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2905
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 14
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -5.27730192805297e-09  (C0 = 0.9999999846714297)
# Golden Section done in 0
#
#
#
# deltaE = -7.4019226303789765e-09    ||g|| = 0.00019555818487294272 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07565375495882
# FCI in Qubits
# (FCI state : E = -76.07567916680985)
#      Basis             Coef
# | 0000111111 > : +0.9874 +0.0000i
#
# (FCI state : E = -75.07030625943538)
#      Basis             Coef
# | 0001111011 > : +0.4439 +0.0000i
# | 0010110111 > : -0.4437 +0.0000i
# | 0011111100 > : -0.1042 +0.0000i
# | 0100111110 > : -0.5410 +0.0000i
# | 1000111101 > : +0.5412 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.075653754959  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#       1: E[sauccgd] = -76.075653760554  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 3.74e-04  CPU Time =    0.28115  (0.01 / step)
#   Final: E[sauccgd] = -76.075653760554  <S**2> = +0.000000  Fidelity = 0.999994  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2891
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 15
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -2.34712720465997e-09  (C0 = 0.9999999893433325)
# Golden Section done in 0
#
#
# """""""""""""""""""""""""""""""""""""""""""""""""""""""
#      Convergence of orbital optimizer with 14 cycles
# """""""""""""""""""""""""""""""""""""""""""""""""""""""
#   Final: E[oo-sauccgd] = -76.07565376055432
