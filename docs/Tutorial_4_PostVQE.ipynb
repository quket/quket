# %% [markdown]
# # Tutorial (4): Post-VQE treatments
#
# Here we show some examples of post-VQE treatments.

# %% [markdown]
# [(0) Prepare and run UCCD](#(0)-Prepare-and-run-UCCD)
# [(1) VQD for excited state calculation](#(1)-VQD-for-excited-state-calculation)
# [(2) Nuclear gradients and geometry optimization](#(2)-Nuclear-gradients-and-geometry-optimization)
# [(3) Orbital optimization](#(3)-Orbital-optimization)

# %%
# import necessary modules
from quket import *
from quket.utils import *
import quket.config as cf
# Out:
# mpi4py is not imported. no MPI.

# %% [markdown]
# ## (0) Prepare and run UCCSD
# For this tutorial, first run SAUCCD-VQE

# %%
### Create QuketData for H2O ###
Q = create(basis="cc-pvdz", 
           ansatz="sauccgd", 
           n_orbitals =5, 
           n_electrons=6, 
           geometry = "O             ;\
                       H 1 1         ;\
                       H 1 1 2 110   ",
           taper_off = True,
           nroots = 2,
           qubitfci = True
        )
# Run UCCD
Q.run()
# Out:
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O     0.0000000    0.0000000    0.0000000
#   H     1.0000000    0.0000000    0.0000000
#   H    -0.3420201    0.0000000    0.9396926
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.024713570960     (Spin = 1   Ms = 0)
#             -75.622866608529     (Spin = 1   Ms = 0)
# E[HF]     = -76.020139776626     (Spin = 1   Ms = 0)
# Overwritten attributes  contract_2e  of <class 'pyscf.fci.direct_spin1_symm.FCISolver'>
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# NBasis = 24
# Davidson convergence achieved.
# FCI in Qubits (tapered-off mapping)
# (FCI state : E = -76.0247135710  multiplicity = 1.0)
#    Basis           Coef
# | 000011 > : -0.9982 +0.0000i
#
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.020139776627  <S**2> = +0.000000  Fidelity = 0.996335  rho = 1
#       1: E[sauccgd] = -76.022752097784  <S**2> = +0.000000  Fidelity = 0.998336  Grad = 1.29e-01  CPU Time =    0.24836  (0.00 / step)
#       2: E[sauccgd] = -76.024032215438  <S**2> = +0.000000  Fidelity = 0.999502  Grad = 8.93e-02  CPU Time =    0.09936  (0.00 / step)
#       3: E[sauccgd] = -76.024439368210  <S**2> = +0.000000  Fidelity = 0.999766  Grad = 6.91e-02  CPU Time =    0.18578  (0.00 / step)
#       4: E[sauccgd] = -76.024570010255  <S**2> = +0.000000  Fidelity = 0.999901  Grad = 2.56e-02  CPU Time =    0.09968  (0.00 / step)
#       5: E[sauccgd] = -76.024596010604  <S**2> = +0.000000  Fidelity = 0.999924  Grad = 1.76e-02  CPU Time =    0.09658  (0.00 / step)
#       6: E[sauccgd] = -76.024626363783  <S**2> = +0.000000  Fidelity = 0.999949  Grad = 4.95e-03  CPU Time =    0.09708  (0.00 / step)
#       7: E[sauccgd] = -76.024629412247  <S**2> = +0.000000  Fidelity = 0.999955  Grad = 4.09e-03  CPU Time =    0.09733  (0.00 / step)
#       8: E[sauccgd] = -76.024633364870  <S**2> = +0.000000  Fidelity = 0.999959  Grad = 4.09e-03  CPU Time =    0.09536  (0.00 / step)
#       9: E[sauccgd] = -76.024638881777  <S**2> = +0.000000  Fidelity = 0.999962  Grad = 4.47e-03  CPU Time =    0.09764  (0.00 / step)
#      10: E[sauccgd] = -76.024664112042  <S**2> = +0.000000  Fidelity = 0.999972  Grad = 8.00e-03  CPU Time =    0.09594  (0.00 / step)
#      11: E[sauccgd] = -76.024687528058  <S**2> = +0.000000  Fidelity = 0.999982  Grad = 8.37e-03  CPU Time =    0.09661  (0.00 / step)
#      12: E[sauccgd] = -76.024694222047  <S**2> = +0.000000  Fidelity = 0.999983  Grad = 1.14e-02  CPU Time =    0.18288  (0.00 / step)
#      13: E[sauccgd] = -76.024706973646  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 3.21e-03  CPU Time =    0.09752  (0.00 / step)
#      14: E[sauccgd] = -76.024708861374  <S**2> = +0.000000  Fidelity = 0.999998  Grad = 9.59e-04  CPU Time =    0.09775  (0.00 / step)
#      15: E[sauccgd] = -76.024708878249  <S**2> = +0.000000  Fidelity = 0.999998  Grad = 2.15e-03  CPU Time =    0.09360  (0.00 / step)
#   Final: E[sauccgd] = -76.024708878249  <S**2> = +0.000000  Fidelity = 0.999998  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9982 +0.0000i
#
#
# VQE Done: CPU Time =          1.7935

# %% [markdown]
# ## (1) VQD for excited state calculation
# `vqd()` prepares for excited state calculation with variational quantum deflation (VQD).
# The previous VQE has to be converged: see
# ```python
#    Q.converge
# ```
# and the penalty parameter is set to the previous energy, `Q.energy`.
# It is also advisable to use an initial state that is approximately orthogonal to the previous states.
#
# #### First copy `Q` to a new `QuketData` instance.

# %%
VQD = Q.copy()

# %% [markdown]
# ### Point-group symmetry
# Due to the point-group symmetry C$2v$ of H$_2$O, the ground state possesses an A$_g$ symmetry.
# The first singlet excited state we aim for should have the same symmetry as the ground state.
# Otherwise, VQD makes no sense especially with qubits being tapered-off by point-group symmetry.
# To ensure the point-group symmetry of the VQD state, it is convenient to look at the MO symmetries.

# %%
VQD.print_mo_energy()
# Out:
# [Molecular Orbitals]
# ---+-------+------------+------------------
#  # |  Sym  |   energy   |     category
# ---+-------+------------+------------------
#  0 |   A1  |   -20.5544 | Frozen Core
#  1 |   A1  |    -1.3121 | Frozen Core
#  2 |   B1  |    -0.6862 | Active (occupied)
#  3 |   A1  |    -0.5477 | Active (occupied)
#  4 |   B2  |    -0.4881 | Active (occupied)
#  5 |   A1  |     0.1785 | Active (virtual)
#  6 |   B1  |     0.2493 | Active (virtual)
#  7 |   B1  |     0.7792 | Secondary
#  8 |   A1  |     0.7921 | Secondary
#  9 |   A1  |     1.1644 | Secondary
# 10 |   B2  |     1.2004 | Secondary
# 11 |   B1  |     1.2501 | Secondary
# 12 |   A2  |     1.4506 | Secondary
# 13 |   A1  |     1.4981 | Secondary
# 14 |   B2  |     1.6943 | Secondary
# 15 |   B1  |     1.8621 | Secondary
# 16 |   A1  |     1.8889 | Secondary
# 17 |   B1  |     2.3708 | Secondary
# 18 |   A1  |     2.3817 | Secondary
# 19 |   B2  |     3.2223 | Secondary
# 20 |   A2  |     3.3175 | Secondary
# 21 |   A1  |     3.4172 | Secondary
# 22 |   A1  |     3.8699 | Secondary
# 23 |   B1  |     4.0674 | Secondary
# ---+-------+------------+------------------

# %% [markdown]
# #### VQD setting with `vqd()`
# Based on the orbital symmetries above, the lowest excited state of $A_g$ is orbital `3` -> orbital `5`.
# To create a singlet state, a two-determinant initial state
# \begin{equation}
# \frac{1}{\sqrt{2}} \left( |0001111011\rangle - |0010110111\rangle\right)
# \end{equation}
# should be prepared.

# %%
VQD.vqd(det="1 * |0001111011> - 1 * |0010110111>")
# Out:
# Performing VQD for excited state 1
# Tapered-off initial state...
# pauli_list transformed.
# Tapered-off pauli list...
# VQD ready. Perform run().

# %% [markdown]
# #### Check the state.
# Note that because of `taper_off = True`, the initial state for VQE is also tapered-off.

# %%
print_state(VQD.init_state)
# Out:
#    Basis           Coef
# | 000111 > : +0.7071 +0.0000i
# | 001010 > : -0.7071 +0.0000i

# %% [markdown]
# #### Backtransform and check the state.
# A tapered state can be backtransformed to the original mapping by `transform_state()`.

# %%
test_state, success = VQD.transform_state(VQD.init_state, backtransform=True)
print("Transformation success?", success)
print_state(test_state)
# Out:
# Transformation success? True
#      Basis             Coef
# | 0001111011 > : +0.7071 +0.0000i
# | 0010110111 > : -0.7071 +0.0000i

# %% [markdown]
# #### This is indeed $\frac{1}{\sqrt{2}} \left( |0001111011\rangle - |0010110111\rangle\right)$.
# ### Now run VQD.

# %%
VQD.run()
# Out:
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration:  +1.0000+0.0000j * |1111011> -1.0000+0.0000j * |10110111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -75.593113704590  <S**2> = -0.000000  Fidelity = 0.000176  rho = 1
#       1: E[sauccgd] = -75.591476707646  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 1.07e+00  CPU Time =    0.33908  (0.00 / step)
#       2: E[sauccgd] = -75.597543526677  <S**2> = +0.000000  Fidelity = 0.000004  Grad = 2.20e+00  CPU Time =    0.26645  (0.00 / step)
#       3: E[sauccgd] = -75.610505662102  <S**2> = +0.000000  Fidelity = 0.000019  Grad = 3.72e+00  CPU Time =    0.09587  (0.00 / step)
#       4: E[sauccgd] = -75.612692928148  <S**2> = +0.000000  Fidelity = 0.000002  Grad = 1.58e+00  CPU Time =    0.09749  (0.00 / step)
#       5: E[sauccgd] = -75.613407236309  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 3.88e-01  CPU Time =    0.09526  (0.00 / step)
#       6: E[sauccgd] = -75.613527881687  <S**2> = +0.000000  Fidelity = 0.000001  Grad = 4.93e-01  CPU Time =    0.09579  (0.00 / step)
#       7: E[sauccgd] = -75.614114472973  <S**2> = +0.000000  Fidelity = 0.000003  Grad = 8.88e-01  CPU Time =    0.09572  (0.00 / step)
#       8: E[sauccgd] = -75.615353152708  <S**2> = +0.000000  Fidelity = 0.000006  Grad = 1.42e+00  CPU Time =    0.09622  (0.00 / step)
#       9: E[sauccgd] = -75.617673352429  <S**2> = +0.000001  Fidelity = 0.000008  Grad = 1.91e+00  CPU Time =    0.11906  (0.00 / step)
#      10: E[sauccgd] = -75.620233729437  <S**2> = +0.000005  Fidelity = 0.000007  Grad = 1.85e+00  CPU Time =    0.09687  (0.00 / step)
#      11: E[sauccgd] = -75.622388074694  <S**2> = +0.000009  Fidelity = 0.000000  Grad = 3.65e-01  CPU Time =    0.09601  (0.00 / step)
#      12: E[sauccgd] = -75.622633560951  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 3.58e-01  CPU Time =    0.09726  (0.00 / step)
#      13: E[sauccgd] = -75.622666163446  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 1.74e-01  CPU Time =    0.09586  (0.00 / step)
#      14: E[sauccgd] = -75.622669074878  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 1.33e-01  CPU Time =    0.09676  (0.00 / step)
#      15: E[sauccgd] = -75.622697513104  <S**2> = +0.000008  Fidelity = 0.000000  Grad = 6.57e-02  CPU Time =    0.09589  (0.00 / step)
#      16: E[sauccgd] = -75.622745769089  <S**2> = +0.000007  Fidelity = 0.000000  Grad = 1.89e-01  CPU Time =    0.09627  (0.00 / step)
#      17: E[sauccgd] = -75.622815128923  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 2.25e-01  CPU Time =    0.09573  (0.00 / step)
#      18: E[sauccgd] = -75.622841560194  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.33e-01  CPU Time =    0.09739  (0.00 / step)
#      19: E[sauccgd] = -75.622841669035  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.61e-02  CPU Time =    0.09868  (0.00 / step)
#      20: E[sauccgd] = -75.622842802987  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 6.08e-03  CPU Time =    0.09629  (0.00 / step)
#      21: E[sauccgd] = -75.622842982919  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 4.59e-03  CPU Time =    0.10041  (0.00 / step)
#      22: E[sauccgd] = -75.622843393877  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 8.46e-03  CPU Time =    0.10056  (0.00 / step)
#      23: E[sauccgd] = -75.622843901514  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.29e-02  CPU Time =    0.10002  (0.00 / step)
#      24: E[sauccgd] = -75.622844347242  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 8.69e-03  CPU Time =    0.09752  (0.00 / step)
#      25: E[sauccgd] = -75.622844435233  <S**2> = +0.000006  Fidelity = 0.000000  Grad = 1.55e-02  CPU Time =    0.18366  (0.00 / step)
#   Final: E[1-sauccgd] = -75.622844435233  <S**2> = +0.000006  Fidelity = 0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000111 > : +0.6928 +0.0000i
# | 001010 > : -0.6953 +0.0000i
# | 001110 > : +0.1076 +0.0000i
#
#
# VQE Done: CPU Time =          2.9567

# %% [markdown]
# #### Note that VQD, especially with generalized UCC, is a highly nonlinear problem and may take a long time to converge.
# ### Check the energy

# %%
print("FCI energies:        ", VQD.fci_energy)
print("SA-UCCGD VQE energy:  ", VQD.lower_states[0]['energy'])
print("SA-UCCGD VQD energy:  ", VQD.energy)
# Out:
# FCI energies:         [-76.02471357095992 -75.62286660852946]
# SA-UCCGD VQE energy:   -76.02470887824937
# SA-UCCGD VQD energy:   -75.62284443523278

# %% [markdown]
# ## (2) Nuclear gradients and geometry optimization
# Nuclear gradient calculation and geometry optimization can be run with `grad()` and `opt()`.
# If qubits are tapered-off, states should be backtransformed because computing reduced density matrices in the reduced mapping is currently not supported.

# %%
Grad = Q.copy()
# Compute nuclear gradients
Grad.taper_off(backtransform=True)
Grad.grad()
# Out:
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0177772    0.0000000   -0.0253885
#   H     0.0450532   -0.0000000   -0.0126284
#   H    -0.0272759   -0.0000000    0.0380170
# *******************************************

# %% [markdown]
# ### Geometry optimization requires the installation of `pyberny`

# %%
OPT = Q.copy()
# Geometry optimization
OPT.taper_off()
OPT.opt()
# Out:
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# Current pauli_list is already tapered-off. No transformation done
# Current theta_list is already tapered-off. No transformation done
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0177772    0.0000000   -0.0253885
#   H     0.0450532   -0.0000000   -0.0126284
#   H    -0.0272759   -0.0000000    0.0380170
# *******************************************
#
# """""""""""""""""""
#      Cycle 0
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0076740    0.0000000   -0.0109596
#   H     0.9435717    0.0000000    0.0476781
#   H    -0.2779178    0.0000000    0.9029742
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030303476378     (Spin = 1   Ms = 0)
#             -75.596953886112     (Spin = 1   Ms = 0)
# E[HF]     = -76.026899177283     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028835013686  <S**2> = +0.000000  Grad = 1.14e-01  CPU Time =    0.23894  (0.00 / step)
#       2: E[sauccgd] = -76.029799060813  <S**2> = +0.000000  Grad = 7.74e-02  CPU Time =    0.09590  (0.00 / step)
#       3: E[sauccgd] = -76.030109459398  <S**2> = +0.000000  Grad = 6.25e-02  CPU Time =    0.18255  (0.00 / step)
#       4: E[sauccgd] = -76.030209530795  <S**2> = +0.000000  Grad = 2.38e-02  CPU Time =    0.09498  (0.00 / step)
#       5: E[sauccgd] = -76.030227919491  <S**2> = +0.000000  Grad = 1.43e-02  CPU Time =    0.09631  (0.00 / step)
#       6: E[sauccgd] = -76.030245293863  <S**2> = +0.000000  Grad = 5.40e-03  CPU Time =    0.09671  (0.00 / step)
#       7: E[sauccgd] = -76.030247599319  <S**2> = +0.000000  Grad = 2.82e-03  CPU Time =    0.09424  (0.00 / step)
#       8: E[sauccgd] = -76.030249021918  <S**2> = +0.000000  Grad = 2.51e-03  CPU Time =    0.09443  (0.00 / step)
#       9: E[sauccgd] = -76.030250636066  <S**2> = +0.000000  Grad = 2.92e-03  CPU Time =    0.09480  (0.00 / step)
#      10: E[sauccgd] = -76.030253796950  <S**2> = +0.000000  Grad = 3.82e-03  CPU Time =    0.09585  (0.00 / step)
#      11: E[sauccgd] = -76.030261307842  <S**2> = +0.000000  Grad = 6.14e-03  CPU Time =    0.09603  (0.00 / step)
#      12: E[sauccgd] = -76.030274019174  <S**2> = +0.000000  Grad = 8.08e-03  CPU Time =    0.09657  (0.00 / step)
#      13: E[sauccgd] = -76.030289245738  <S**2> = +0.000000  Grad = 8.64e-03  CPU Time =    0.09627  (0.00 / step)
#      14: E[sauccgd] = -76.030296368753  <S**2> = +0.000000  Grad = 1.02e-02  CPU Time =    0.09670  (0.00 / step)
#      15: E[sauccgd] = -76.030299374435  <S**2> = +0.000000  Grad = 6.84e-03  CPU Time =    0.09395  (0.00 / step)
#      16: E[sauccgd] = -76.030300221345  <S**2> = +0.000000  Grad = 7.21e-04  CPU Time =    0.09615  (0.00 / step)
#      17: E[sauccgd] = -76.030300243626  <S**2> = +0.000000  Grad = 4.14e-04  CPU Time =    0.09425  (0.00 / step)
#   Final: E[sauccgd] = -76.030300243626  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# pauli_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0009884   -0.0000000   -0.0014116
#   H    -0.0004062   -0.0000000    0.0013363
#   H     0.0013946    0.0000000    0.0000754
# *******************************************
#
# """""""""""""""""""
#      Cycle 1
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0059431    0.0000000   -0.0084876
#   H     0.9458339    0.0000000    0.0442520
#   H    -0.2819109    0.0000000    0.9039282
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030319533945     (Spin = 1   Ms = 0)
#             -75.598326847387     (Spin = 1   Ms = 0)
# E[HF]     = -76.026936384182     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028862077560  <S**2> = +0.000000  Grad = 1.14e-01  CPU Time =    0.24336  (0.00 / step)
#       2: E[sauccgd] = -76.029822612460  <S**2> = +0.000000  Grad = 7.70e-02  CPU Time =    0.11752  (0.00 / step)
#       3: E[sauccgd] = -76.030127277626  <S**2> = +0.000000  Grad = 6.21e-02  CPU Time =    0.18182  (0.00 / step)
#       4: E[sauccgd] = -76.030226582358  <S**2> = +0.000000  Grad = 2.34e-02  CPU Time =    0.09701  (0.00 / step)
#       5: E[sauccgd] = -76.030244694806  <S**2> = +0.000000  Grad = 1.43e-02  CPU Time =    0.09656  (0.00 / step)
#       6: E[sauccgd] = -76.030262254127  <S**2> = +0.000000  Grad = 5.06e-03  CPU Time =    0.09648  (0.00 / step)
#       7: E[sauccgd] = -76.030264410182  <S**2> = +0.000000  Grad = 2.76e-03  CPU Time =    0.09706  (0.00 / step)
#       8: E[sauccgd] = -76.030265940538  <S**2> = +0.000000  Grad = 2.47e-03  CPU Time =    0.09631  (0.00 / step)
#       9: E[sauccgd] = -76.030267538297  <S**2> = +0.000000  Grad = 2.87e-03  CPU Time =    0.09681  (0.00 / step)
#      10: E[sauccgd] = -76.030271119588  <S**2> = +0.000000  Grad = 3.94e-03  CPU Time =    0.09400  (0.00 / step)
#      11: E[sauccgd] = -76.030278832107  <S**2> = +0.000000  Grad = 6.58e-03  CPU Time =    0.09664  (0.00 / step)
#      12: E[sauccgd] = -76.030291577948  <S**2> = +0.000000  Grad = 7.67e-03  CPU Time =    0.09438  (0.00 / step)
#      13: E[sauccgd] = -76.030306675446  <S**2> = +0.000000  Grad = 9.58e-03  CPU Time =    0.09607  (0.00 / step)
#      14: E[sauccgd] = -76.030314474203  <S**2> = +0.000000  Grad = 5.77e-03  CPU Time =    0.09765  (0.00 / step)
#      15: E[sauccgd] = -76.030315331279  <S**2> = +0.000000  Grad = 7.59e-03  CPU Time =    0.09770  (0.00 / step)
#      16: E[sauccgd] = -76.030316314233  <S**2> = +0.000000  Grad = 6.33e-04  CPU Time =    0.09611  (0.00 / step)
#      17: E[sauccgd] = -76.030316335031  <S**2> = +0.000000  Grad = 4.03e-04  CPU Time =    0.09873  (0.00 / step)
#   Final: E[sauccgd] = -76.030316335031  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# pauli_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O    -0.0002999    0.0000000   -0.0004283
#   H     0.0003080    0.0000000    0.0001035
#   H    -0.0000080   -0.0000000    0.0003248
# *******************************************
#
# """""""""""""""""""
#      Cycle 2
# """""""""""""""""""
# Basis set = cc-pvdz
#
# *** Geometry ******************************
#   O    -0.0056954    0.0000000   -0.0081339
#   H     0.9457480    0.0000000    0.0440487
#   H    -0.2820726    0.0000000    0.9037779
# *******************************************
#
# Symmetry C2v : C2v(Abelian)
# E[FCI]    = -76.030319776873     (Spin = 1   Ms = 0)
#             -75.598306322278     (Spin = 1   Ms = 0)
# E[HF]     = -76.026948785366     (Spin = 1   Ms = 0)
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# Tapering-Off Results:
# List of redundant qubits:  [0, 1, 2, 4]
# Qubit: 0    Tau: 1.0 [Z0 Z3 Z5 Z7 Z8]
# Qubit: 1    Tau: 1.0 [Z1 Z3 Z5 Z7 Z9]
# Qubit: 2    Tau: 1.0 [Z2 Z3 Z6 Z7]
# Qubit: 4    Tau: 1.0 [Z4 Z5]
#
# Current states are already tapered-off. No transformation done
# Current operators are already tapered-off. No transformation done
# pauli_list transformed.
#       1: E[sauccgd] = -76.028867804721  <S**2> = +0.000000  Grad = 1.13e-01  CPU Time =    0.23609  (0.00 / step)
#       2: E[sauccgd] = -76.029825462856  <S**2> = +0.000000  Grad = 7.68e-02  CPU Time =    0.09626  (0.00 / step)
#       3: E[sauccgd] = -76.030128399234  <S**2> = +0.000000  Grad = 6.20e-02  CPU Time =    0.18387  (0.00 / step)
#       4: E[sauccgd] = -76.030227340732  <S**2> = +0.000000  Grad = 2.33e-02  CPU Time =    0.09638  (0.00 / step)
#       5: E[sauccgd] = -76.030245354078  <S**2> = +0.000000  Grad = 1.42e-02  CPU Time =    0.09705  (0.00 / step)
#       6: E[sauccgd] = -76.030262857483  <S**2> = +0.000000  Grad = 5.02e-03  CPU Time =    0.11737  (0.00 / step)
#       7: E[sauccgd] = -76.030264988111  <S**2> = +0.000000  Grad = 2.74e-03  CPU Time =    0.09531  (0.00 / step)
#       8: E[sauccgd] = -76.030266522730  <S**2> = +0.000000  Grad = 2.46e-03  CPU Time =    0.09676  (0.00 / step)
#       9: E[sauccgd] = -76.030268105986  <S**2> = +0.000000  Grad = 2.85e-03  CPU Time =    0.09642  (0.00 / step)
#      10: E[sauccgd] = -76.030271715773  <S**2> = +0.000000  Grad = 3.94e-03  CPU Time =    0.09688  (0.00 / step)
#      11: E[sauccgd] = -76.030279382397  <S**2> = +0.000000  Grad = 6.62e-03  CPU Time =    0.09807  (0.00 / step)
#      12: E[sauccgd] = -76.030292057998  <S**2> = +0.000000  Grad = 7.61e-03  CPU Time =    0.11561  (0.00 / step)
#      13: E[sauccgd] = -76.030307060848  <S**2> = +0.000000  Grad = 9.82e-03  CPU Time =    0.09782  (0.00 / step)
#      14: E[sauccgd] = -76.030314895136  <S**2> = +0.000000  Grad = 5.19e-03  CPU Time =    0.09737  (0.00 / step)
#      15: E[sauccgd] = -76.030315721974  <S**2> = +0.000000  Grad = 7.14e-03  CPU Time =    0.09667  (0.00 / step)
#      16: E[sauccgd] = -76.030316574589  <S**2> = +0.000000  Grad = 6.44e-04  CPU Time =    0.09683  (0.00 / step)
#      17: E[sauccgd] = -76.030316595800  <S**2> = +0.000000  Grad = 3.91e-04  CPU Time =    0.09860  (0.00 / step)
#   Final: E[sauccgd] = -76.030316595800  <S**2> = +0.000000  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9987 +0.0000i
#
# VQE Done.
# States     backtransformed.
# Operators  backtransformed.
# Existing theta_list is inconsistent :
#    size of pauli_list 150 != size of theta_list 38.
# Ovewrite theta_list by zero.
# pauli_list backtransformed.
#  === Computing 1RDM ===
#  === Computing 2RDM ===
#
# *** Nuclear Gradients *********************
#             x            y            z
#   O     0.0000245    0.0000000    0.0000350
#   H    -0.0000337   -0.0000000   -0.0000025
#   H     0.0000092   -0.0000000   -0.0000325
# *******************************************
#
# Geometry Optimization Converged in 2 cycles
#
# *** Geometry ******************************
#   O    -0.0056954    0.0000000   -0.0081339
#   H     0.9457480    0.0000000    0.0440487
#   H    -0.2820726    0.0000000    0.9037779
# *******************************************

# %% [markdown]
# ## (3) Orbital optimization
# `oo()` performs orbital optimization.
# It assumes the method is VQE, but works for most ansatze.

# %%
# This example provides oo-SAUCCD
OO = Q.copy()
OO.oo()
# Out:
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 1
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.032562491087009524  (C0 = 0.5420956622835309)
# Golden Section done in 2
#
#
#
# ||g|| = 0.03480523170083466 ---> Updated with scaling factor 0.8594235253127366
#
#
# Next energy estimation:  -76.05014212152284
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0693695570  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : +0.9895 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.050142121524  <S**2> = +0.000000  Fidelity = 0.991760  rho = 1
#       1: E[sauccgd] = -76.060149028491  <S**2> = +0.000000  Fidelity = 0.995146  Grad = 3.96e-01  CPU Time =    0.28359  (0.00 / step)
#       2: E[sauccgd] = -76.063923377376  <S**2> = +0.000000  Fidelity = 0.997325  Grad = 2.22e-01  CPU Time =    0.09640  (0.00 / step)
#       3: E[sauccgd] = -76.067163471734  <S**2> = +0.000000  Fidelity = 0.999152  Grad = 1.58e-01  CPU Time =    0.09731  (0.00 / step)
#       4: E[sauccgd] = -76.067569188788  <S**2> = +0.000000  Fidelity = 0.999382  Grad = 1.26e-01  CPU Time =    0.18361  (0.00 / step)
#       5: E[sauccgd] = -76.067847029270  <S**2> = +0.000000  Fidelity = 0.999513  Grad = 8.84e-02  CPU Time =    0.09757  (0.00 / step)
#       6: E[sauccgd] = -76.068278933038  <S**2> = +0.000000  Fidelity = 0.999680  Grad = 6.32e-02  CPU Time =    0.09712  (0.00 / step)
#       7: E[sauccgd] = -76.068451286986  <S**2> = +0.000000  Fidelity = 0.999685  Grad = 9.82e-02  CPU Time =    0.09572  (0.00 / step)
#       8: E[sauccgd] = -76.068612904974  <S**2> = +0.000000  Fidelity = 0.999766  Grad = 5.37e-02  CPU Time =    0.09688  (0.00 / step)
#       9: E[sauccgd] = -76.068788482017  <S**2> = +0.000000  Fidelity = 0.999808  Grad = 5.35e-02  CPU Time =    0.09859  (0.00 / step)
#      10: E[sauccgd] = -76.068986315823  <S**2> = +0.000000  Fidelity = 0.999852  Grad = 7.00e-02  CPU Time =    0.09671  (0.00 / step)
#      11: E[sauccgd] = -76.069234392282  <S**2> = +0.000000  Fidelity = 0.999938  Grad = 5.04e-02  CPU Time =    0.09589  (0.00 / step)
#      12: E[sauccgd] = -76.069300772763  <S**2> = +0.000000  Fidelity = 0.999977  Grad = 1.59e-02  CPU Time =    0.09610  (0.00 / step)
#      13: E[sauccgd] = -76.069304824215  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 4.71e-03  CPU Time =    0.09625  (0.00 / step)
#      14: E[sauccgd] = -76.069306256554  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 6.35e-03  CPU Time =    0.09896  (0.00 / step)
#      15: E[sauccgd] = -76.069307936788  <S**2> = +0.000000  Fidelity = 0.999980  Grad = 1.05e-02  CPU Time =    0.09647  (0.00 / step)
#      16: E[sauccgd] = -76.069311717698  <S**2> = +0.000000  Fidelity = 0.999981  Grad = 1.62e-02  CPU Time =    0.09619  (0.00 / step)
#      17: E[sauccgd] = -76.069318413812  <S**2> = +0.000000  Fidelity = 0.999982  Grad = 2.04e-02  CPU Time =    0.09420  (0.00 / step)
#      18: E[sauccgd] = -76.069330942110  <S**2> = +0.000000  Fidelity = 0.999984  Grad = 2.29e-02  CPU Time =    0.09689  (0.00 / step)
#      19: E[sauccgd] = -76.069338404493  <S**2> = +0.000000  Fidelity = 0.999987  Grad = 2.62e-02  CPU Time =    0.18501  (0.00 / step)
#      20: E[sauccgd] = -76.069349069034  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 1.22e-02  CPU Time =    0.09678  (0.00 / step)
#      21: E[sauccgd] = -76.069353626563  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 3.33e-03  CPU Time =    0.09727  (0.00 / step)
#      22: E[sauccgd] = -76.069354070521  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 3.02e-03  CPU Time =    0.11874  (0.00 / step)
#      23: E[sauccgd] = -76.069354454174  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.60e-03  CPU Time =    0.09736  (0.00 / step)
#      24: E[sauccgd] = -76.069354576743  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 8.15e-04  CPU Time =    0.09553  (0.00 / step)
#      25: E[sauccgd] = -76.069354604466  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 8.83e-04  CPU Time =    0.09795  (0.00 / step)
#   Final: E[sauccgd] = -76.069354604466  <S**2> = +0.000000  Fidelity = 0.999995  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9895 +0.0000i
#
#
# VQE Done: CPU Time =          2.8140
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 2
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.009984340964364744  (C0 = 0.8955185301719596)
# Golden Section done in 0
#
#
#
# deltaE = -0.044645726216856474    ||g|| = 0.05632613278772486 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07397154107832
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0745728226  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9880 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.073971541078  <S**2> = +0.000000  Fidelity = 0.999682  rho = 1
#       1: E[sauccgd] = -76.074291198369  <S**2> = +0.000000  Fidelity = 0.999867  Grad = 6.77e-02  CPU Time =    0.28576  (0.00 / step)
#       2: E[sauccgd] = -76.074455866572  <S**2> = +0.000000  Fidelity = 0.999947  Grad = 4.14e-02  CPU Time =    0.09622  (0.00 / step)
#       3: E[sauccgd] = -76.074482501772  <S**2> = +0.000000  Fidelity = 0.999944  Grad = 7.34e-02  CPU Time =    0.09756  (0.00 / step)
#       4: E[sauccgd] = -76.074541477482  <S**2> = +0.000000  Fidelity = 0.999988  Grad = 1.91e-02  CPU Time =    0.09783  (0.00 / step)
#       5: E[sauccgd] = -76.074547094905  <S**2> = +0.000000  Fidelity = 0.999991  Grad = 1.08e-02  CPU Time =    0.09784  (0.00 / step)
#       6: E[sauccgd] = -76.074553179968  <S**2> = +0.000000  Fidelity = 0.999993  Grad = 6.00e-03  CPU Time =    0.09596  (0.00 / step)
#       7: E[sauccgd] = -76.074555582133  <S**2> = +0.000000  Fidelity = 0.999994  Grad = 1.79e-03  CPU Time =    0.09700  (0.00 / step)
#       8: E[sauccgd] = -76.074555953549  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.46e-03  CPU Time =    0.09834  (0.00 / step)
#       9: E[sauccgd] = -76.074557014226  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 2.16e-03  CPU Time =    0.09784  (0.00 / step)
#      10: E[sauccgd] = -76.074557320331  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 4.94e-03  CPU Time =    0.09692  (0.00 / step)
#      11: E[sauccgd] = -76.074557849779  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 1.98e-03  CPU Time =    0.09690  (0.00 / step)
#      12: E[sauccgd] = -76.074558243984  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.49e-03  CPU Time =    0.09596  (0.00 / step)
#      13: E[sauccgd] = -76.074558614947  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.71e-03  CPU Time =    0.09626  (0.00 / step)
#      14: E[sauccgd] = -76.074559360897  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.81e-03  CPU Time =    0.09826  (0.00 / step)
#      15: E[sauccgd] = -76.074559809996  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 4.22e-03  CPU Time =    0.18389  (0.00 / step)
#      16: E[sauccgd] = -76.074560769613  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 1.76e-03  CPU Time =    0.09791  (0.00 / step)
#      17: E[sauccgd] = -76.074560895095  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 3.55e-03  CPU Time =    0.09815  (0.00 / step)
#      18: E[sauccgd] = -76.074561060640  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 9.87e-04  CPU Time =    0.09796  (0.00 / step)
#      19: E[sauccgd] = -76.074561087054  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 6.94e-04  CPU Time =    0.09827  (0.00 / step)
#   Final: E[sauccgd] = -76.074561087054  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9880 +0.0000i
#
#
# VQE Done: CPU Time =          2.1360
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 3
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -0.0006187306665449949  (C0 = 0.9975033819353147)
# Golden Section done in 0
#
#
#
# deltaE = -0.005206482587752248    ||g|| = 0.01718441183162869 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07485161508926
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0748854322  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9876 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074851615089  <S**2> = +0.000000  Fidelity = 0.999985  rho = 1
#       1: E[sauccgd] = -76.074864269545  <S**2> = +0.000000  Fidelity = 0.999992  Grad = 1.22e-02  CPU Time =    0.28570  (0.00 / step)
#       2: E[sauccgd] = -76.074871313675  <S**2> = +0.000000  Fidelity = 0.999995  Grad = 6.63e-03  CPU Time =    0.09955  (0.00 / step)
#       3: E[sauccgd] = -76.074872696350  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 8.19e-03  CPU Time =    0.18499  (0.00 / step)
#       4: E[sauccgd] = -76.074873821743  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 3.00e-03  CPU Time =    0.11939  (0.00 / step)
#       5: E[sauccgd] = -76.074874103982  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.06e-03  CPU Time =    0.09762  (0.00 / step)
#       6: E[sauccgd] = -76.074874318395  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.34e-03  CPU Time =    0.09829  (0.00 / step)
#       7: E[sauccgd] = -76.074874421087  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.24e-03  CPU Time =    0.09878  (0.00 / step)
#       8: E[sauccgd] = -76.074874463542  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.22e-03  CPU Time =    0.09837  (0.00 / step)
#   Final: E[sauccgd] = -76.074874463542  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9876 +0.0000i
#
#
# VQE Done: CPU Time =          1.0930
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 4
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -7.552819534964611e-05  (C0 = 0.9996897595596279)
# Golden Section done in 0
#
#
#
# deltaE = -0.00031337648752582936    ||g|| = 0.005725565133971891 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07490987079957
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0749240404  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9875 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074909870800  <S**2> = +0.000000  Fidelity = 0.999995  rho = 1
#       1: E[sauccgd] = -76.074911646628  <S**2> = +0.000000  Fidelity = 0.999996  Grad = 4.61e-03  CPU Time =    0.28744  (0.00 / step)
#       2: E[sauccgd] = -76.074912654720  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.60e-03  CPU Time =    0.09738  (0.00 / step)
#       3: E[sauccgd] = -76.074913179621  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 2.26e-03  CPU Time =    0.09883  (0.00 / step)
#       4: E[sauccgd] = -76.074913274729  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.18e-03  CPU Time =    0.18632  (0.00 / step)
#       5: E[sauccgd] = -76.074913324159  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 9.80e-04  CPU Time =    0.09847  (0.00 / step)
#   Final: E[sauccgd] = -76.074913324159  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9875 +0.0000i
#
#
# VQE Done: CPU Time =          0.7784
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 5
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -1.0399141490251195e-05  (C0 = 0.9999567539581837)
# Golden Section done in 0
#
#
#
# deltaE = -3.886061740843161e-05    ||g|| = 0.0020776654779799107 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07491819842645
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0749293169  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9875 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074918198426  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074918431516  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.89e-03  CPU Time =    0.32493  (0.00 / step)
#       2: E[sauccgd] = -76.074918568542  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.44e-03  CPU Time =    0.09984  (0.00 / step)
#       3: E[sauccgd] = -76.074918657761  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 3.17e-03  CPU Time =    0.10254  (0.00 / step)
#       4: E[sauccgd] = -76.074918778438  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.29e-03  CPU Time =    0.10102  (0.00 / step)
#       5: E[sauccgd] = -76.074918812769  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.04e-03  CPU Time =    0.09894  (0.00 / step)
#   Final: E[sauccgd] = -76.074918812769  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.7378
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 6
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -1.5171382468831471e-06  (C0 = 0.9999936300920447)
# Golden Section done in 0
#
#
#
# deltaE = -5.488609673420797e-06    ||g|| = 0.0007607781565296364 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07491952389572
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0749300639  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9874 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074919523895  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074919548404  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.95e-03  CPU Time =    0.28976  (0.00 / step)
#   Final: E[sauccgd] = -76.074919548404  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2999
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 7
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -2.191702656306795e-07  (C0 = 0.9999992745171455)
# Golden Section done in 0
#
#
#
# deltaE = -7.356357656362889e-07    ||g|| = 0.0007566060131055202 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.0749196511385
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0749301474  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9874 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074919651138  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074919687963  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.54e-03  CPU Time =    0.28540  (0.00 / step)
#   Final: E[sauccgd] = -76.074919687963  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.2956
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 8
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -3.09685690334303e-08  (C0 = 0.9999999259620337)
# Golden Section done in 0
#
#
#
# deltaE = -1.3955877875559963e-07    ||g|| = 0.0003332199901948213 ---> Updated with scaling factor 0.75
#
#
# Next energy estimation:  -76.07491970248006
# Davidson convergence achieved.
# FCI in Qubits
# (FCI state : E = -76.0749301667  multiplicity = 1.0)
#      Basis             Coef
# | 0000111111 > : -0.9874 +0.0000i
#
# States     transformed.
# Operators  transformed.
# pauli_list transformed.
# theta_list transformed.
# Entered VQE driver
# Performing VQE for sauccgd
# Number of VQE parameters: 38
# Initial configuration: |111111>
# Convergence criteria: ftol = 1E-09, gtol = 1E-05
# Derivatives: Analytical
# Circuit order: Exp[T1] Exp[T2] |0>
# Initial: E[sauccgd] = -76.074919702480  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#       1: E[sauccgd] = -76.074919739473  <S**2> = +0.000000  Fidelity = 0.999997  Grad = 1.27e-03  CPU Time =    0.28967  (0.00 / step)
#   Final: E[sauccgd] = -76.074919739473  <S**2> = +0.000000  Fidelity = 0.999997  rho = 1
#
# (sauccgd state)
#    Basis           Coef
# | 000011 > : +0.9874 +0.0000i
#
#
# VQE Done: CPU Time =          0.3022
#
#
# States     backtransformed.
# Operators  backtransformed.
# pauli_list backtransformed.
# theta_list backtransformed.
#
#
# """"""""""""""""""""""""""""""""""""""
#      Orbital-Optimization Cycle 9
# """"""""""""""""""""""""""""""""""""""
#
#  === Computing 1RDM ===
#  === Computing 2RDM ===
# Running Davidson to get update by AH
# Target lowest eigenvalue of augmented Hessian:  -3.646629891814129e-08  (C0 = 0.9999999331616178)
# Golden Section done in 0
#
#
# """""""""""""""""""""""""""""""""""""""""""""""""""""""
#      Convergence of orbital optimizer with 8 cycles
# """""""""""""""""""""""""""""""""""""""""""""""""""""""
#   Final: E[oo-sauccgd] = -76.0749197394725
